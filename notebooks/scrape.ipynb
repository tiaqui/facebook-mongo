# %%
from facebook_scraper import get_posts

# %% [markdown]
# group: group id, to scrape groups instead of pages. Default is None.
#
# pages: how many pages of posts to request, the first 2 pages may have no results, so try with a number greater than 2. Default is 10.
#
# timeout: how many seconds to wait before timing out. Default is 5.
#
# credentials: tuple of user and password to login before requesting the posts. Default is None.
#
# extra_info: bool, if true the function will try to do an extra request to get the post reactions. Default is False.
#
# youtube_dl: bool, use Youtube-DL for (high-quality) video extraction. You need to have youtube-dl installed on your
# environment. Default is False.
#
# post_urls: list, URLs or post IDs to extract posts from. Alternative to fetching based on username.
#
# cookies: One of:
# The path to a file containing cookies in Netscape or JSON format. You can extract cookies from your browser after logging into Facebook with an extension like EditThisCookie (Chrome) or Cookie Quick Manager (Firefox). Make sure that you include both the c_user cookie and the xs cookie, you will get an InvalidCookies exception if you don't.
# A CookieJar
# A dictionary that can be converted to a CookieJar with cookiejar_from_dict
#
# options: Dictionary of options. Set options={"comments": True} to extract comments, set options={"reactors": True} to extract the people reacting to the post. Both comments and reactors can also be set to a number to set a limit for the amount of comments/reactors to retrieve. The default limit for comments is 5000 and the default limit for reactors is 3000. Set options={"progress": True} to get a tqdm progress bar while extracting comments and replies. Set options={"allow_extra_requests": False} to disable making extra requests when extracting post data (required for some things like full text and image links). Set options={"posts_per_page": 200} to request 200 posts per page. The default is 4.

# %%
import copy
import yaml
import sqlalchemy
from facebook_scraper import get_posts

DOMAIN = "localhost"
PORT = "5432"
PAGE_NAME = "coherenciaporfavor"
DB_NAME = "scrapes"


def fetch_posts(
    page=PAGE_NAME,
    pages=10,
    credentials=None,
    post_urls=None,
    cookies=None,
    options=None,
):

    if post_urls:
        if page:
            print("Ignoring 'page' argument.")

        return [
            post
            for post in get_posts(
                credentials=credentials,
                post_urls=post_urls,
                cookies=cookies,
                options=options,
            )
        ]
    print(options)
    return [
        post
        for post in get_posts(
            page,
            pages=pages,
            credentials=credentials,
            cookies=cookies,
            options=options,
        )
    ]


def get_objects(posts):
    posts_c = copy.deepcopy(posts)
    p, c, r = [], [], []

    for post in posts_c:
        if post["comments_full"]:
            comments = post["comments_full"]
            for comment in comments:
                comment["_post_id"] = post["post_id"]

                if "replies" in comment:

                    for reply in comment["replies"]:
                        reply["_comment_id"] = comment["comment_id"]
                        r.append(reply)
                    del comment["replies"]

                c.append(comment)

        del post["comments_full"]
        p.append(post)

    return p, c, r


def fetch_scrape_args(filepath="scrape_args.yml"):

    with open(filepath, "r") as file:
        args = yaml.safe_load(file)

        credentials = None
        if args["credentials"]["user"] and args["credentials"]["password"]:
            credentials = (args["credentials"]["user"], args["credentials"]["password"])

        page = args["page"] if args["page"] else None
        pages = args["pages"] if args["pages"] else None
        post_urls = args["post_urls"] if args["post_urls"] else None
        cookies = args["cookies"] if args["cookies"] else None

    return [
        page,
        credentials,
        pages,
        post_urls,
        cookies,
        {
            k: args[k]
            for k in ["comments", "progress", "reactors", "posts_per_page"]
            if k in args
        },
    ]

# %%
page, credentials, pages, post_urls, cookies, options = fetch_scrape_args(
    "../scrape_args.yml"
)

# %%
pages = 2

# %%
page, credentials, pages, post_urls, cookies, options = fetch_scrape_args(
    "../scrape_args.yml"
)

posts = fetch_posts(
    page=page,
    pages=pages,
    post_urls=post_urls,
    credentials=credentials,
#    cookies=cookies,
    options=options,
)

posts, comments, replies = get_objects(posts)

# %%
posts = fetch_posts(
    page=page,
    pages=pages,
    post_urls=post_urls,
    credentials=credentials,
#    cookies=cookies,
    options=options,
)
# Out:
# Ignoring 'page' argument.
# /Users/tiaqui/Documents/Code/facebook_scraper/fb_scraper/lib/python3.9/site-packages/facebook_scraper/facebook_scraper.py:278: UserWarning: Locale detected as es_LA - for best results, set to en_US
#   warnings.warn(f"Locale detected as {locale} - for best results, set to en_US")
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
posts, comments, replies = get_objects(posts)

# %%
posts
# Out:
# [{'original_request_url': 1584781918529337,
#   'post_url': 'https://m.facebook.com/1584781958529333',
#   'post_id': '1584781958529333',
#   'text': 'Coherencia Por Favor',
#   'post_text': 'Coherencia Por Favor',
#   'shared_text': None,
#   'time': datetime.datetime(2021, 7, 26, 0, 0),
#   'image': 'https://scontent.faep9-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/217326948_1584781928529336_8731486713886378979_n.jpg?_nc_cat=103&ccb=1-5&_nc_sid=110474&_nc_ohc=uf6JtHOlFNwAX_E4CGQ&_nc_ht=scontent.faep9-1.fna&oh=4260765b26eb82ee3cdc3c9c809dd766&oe=6154332F',
#   'image_lowquality': 'https://scontent.faep9-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/217326948_1584781928529336_8731486713886378979_n.jpg?_nc_cat=103&ccb=1-5&_nc_sid=110474&_nc_ohc=uf6JtHOlFNwAX_E4CGQ&_nc_ht=scontent.faep9-1.fna&oh=4260765b26eb82ee3cdc3c9c809dd766&oe=6154332F',
#   'images': ['https://scontent.faep9-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/217326948_1584781928529336_8731486713886378979_n.jpg?_nc_cat=103&ccb=1-5&_nc_sid=110474&_nc_ohc=uf6JtHOlFNwAX_E4CGQ&_nc_ht=scontent.faep9-1.fna&oh=4260765b26eb82ee3cdc3c9c809dd766&oe=6154332F'],
#   'images_description': None,
#   'images_lowquality': ['https://scontent.faep9-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/217326948_1584781928529336_8731486713886378979_n.jpg?_nc_cat=103&ccb=1-5&_nc_sid=110474&_nc_ohc=uf6JtHOlFNwAX_E4CGQ&_nc_ht=scontent.faep9-1.fna&oh=4260765b26eb82ee3cdc3c9c809dd766&oe=6154332F'],
#   'images_lowquality_description': ['Puede ser una imagen de texto que dice "Yo con las 2 dosis de la vacuna Nueva cepa Coherencia por favor"'],
#   'video': None,
#   'video_duration_seconds': None,
#   'video_height': None,
#   'video_id': None,
#   'video_quality': None,
#   'video_size_MB': None,
#   'video_thumbnail': None,
#   'video_watches': None,
#   'video_width': None,
#   'likes': 674,
#   'comments': 22,
#   'shares': 747,
#   'link': 'https://media1.tenor.co/images/90b44a6dab0064c391aafa1f98745ebf/tenor.gif?itemid=14267640',
#   'user_id': '347304572277084',
#   'username': 'Coherencia Por Favor',
#   'user_url': 'https://facebook.com/coherenciaporfavor/?__tn__=%2Cg',
#   'is_live': False,
#   'factcheck': None,
#   'shared_post_id': None,
#   'shared_time': None,
#   'shared_user_id': None,
#   'shared_username': None,
#   'shared_post_url': None,
#   'available': True,
#   'reactors': None,
#   'w3_fb_url': None,
#   'reactions': None,
#   'reaction_count': None},
#  {'original_request_url': 1590404371300425,
#   'post_url': 'https://facebook.com/story.php?story_fbid=1590404371300425&id=347304572277084',
#   'post_id': '1590404371300425',
#   'text': '',
#   'post_text': '',
#   'shared_text': None,
#   'time': datetime.datetime(2021, 8, 3, 18, 12, 25),
#   'image': 'https://scontent.faep9-2.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/229104666_1590404247967104_6671068575503839345_n.jpg?_nc_cat=110&ccb=1-5&_nc_sid=110474&_nc_ohc=6hp5KqROBGIAX8EcvdX&_nc_ht=scontent.faep9-2.fna&oh=e6bc09d6cc29eeccb999769ed4fcb94b&oe=6153DCE7',
#   'image_lowquality': 'https://scontent.faep9-2.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/229104666_1590404247967104_6671068575503839345_n.jpg?_nc_cat=110&ccb=1-5&_nc_sid=110474&_nc_ohc=6hp5KqROBGIAX8EcvdX&_nc_ht=scontent.faep9-2.fna&oh=e6bc09d6cc29eeccb999769ed4fcb94b&oe=6153DCE7',
#   'images': ['https://scontent.faep9-2.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/229104666_1590404247967104_6671068575503839345_n.jpg?_nc_cat=110&ccb=1-5&_nc_sid=110474&_nc_ohc=6hp5KqROBGIAX8EcvdX&_nc_ht=scontent.faep9-2.fna&oh=e6bc09d6cc29eeccb999769ed4fcb94b&oe=6153DCE7'],
#   'images_description': ['Puede ser una imagen de texto que dice "ANSES -Hola, venís por un Plan? permitime tu DNI -No, en realidad venía para inscribir una PyME. -Ah, para eso tenés que ir la AFIP, llenás las solicitudes y después emepezás a pagar IVA, ingresos brutos, alquiler, ART, seguro de vida, seguros sociales, retenciones, percepciones, luz, agua, cuenta del banco, impuesto al cheque, sueldos, abogados, contadores y si te queda ganancia: impuesto a las ganancias y si llegás a hacerte rica: impuesto a la riqueza! Coherencia por favor"'],
#   'images_lowquality': ['https://scontent.faep9-2.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/229104666_1590404247967104_6671068575503839345_n.jpg?_nc_cat=110&ccb=1-5&_nc_sid=110474&_nc_ohc=6hp5KqROBGIAX8EcvdX&_nc_ht=scontent.faep9-2.fna&oh=e6bc09d6cc29eeccb999769ed4fcb94b&oe=6153DCE7'],
#   'images_lowquality_description': ['Puede ser una imagen de texto que dice "ANSES -Hola, venís por un Plan? permitime tu DNI -No, en realidad venía para inscribir una PyME. -Ah, para eso tenés que ir la AFIP, llenás las solicitudes y después emepezás a pagar IVA, ingresos brutos, alquiler, ART, seguro de vida, seguros sociales, retenciones, percepciones, luz, agua, cuenta del banco, impuesto al cheque, sueldos, abogados, contadores y si te queda ganancia: impuesto a las ganancias y si llegás a hacerte rica: impuesto a la riqueza! Coherencia por favor"'],
#   'video': None,
#   'video_duration_seconds': None,
#   'video_height': None,
#   'video_id': None,
#   'video_quality': None,
#   'video_size_MB': None,
#   'video_thumbnail': None,
#   'video_watches': None,
#   'video_width': None,
#   'likes': 930,
#   'comments': 46,
#   'shares': 1059,
#   'link': None,
#   'user_id': '347304572277084',
#   'username': 'Coherencia Por Favor',
#   'user_url': 'https://facebook.com/coherenciaporfavor/?refid=52&__tn__=C-R',
#   'is_live': False,
#   'factcheck': None,
#   'shared_post_id': None,
#   'shared_time': None,
#   'shared_user_id': None,
#   'shared_username': None,
#   'shared_post_url': None,
#   'available': True,
#   'reactors': None,
#   'w3_fb_url': None,
#   'reactions': None,
#   'reaction_count': None,
#   'image_id': '1590404241300438',
#   'image_ids': ['1590404241300438']}]

# %%
comments
# Out:
# [{'comment_id': '1584803675193828',
#   'comment_url': 'https://facebook.com/1584803675193828',
#   'commenter_id': '100026229755116',
#   'commenter_url': None,
#   'commenter_name': 'Nestor Paladino',
#   'commenter_meta': None,
#   'comment_text': '¿ Nueva "cepa Robin Hood" ..?🏹🤣🏹🤣',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584783685195827',
#   'comment_url': 'https://facebook.com/1584783685195827',
#   'commenter_id': '100005306702370',
#   'commenter_url': None,
#   'commenter_name': 'Analia Gabriela',
#   'commenter_meta': None,
#   'comment_text': 'La nueva cepa se llama Hawkeye.',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1585255635148632',
#   'comment_url': 'https://facebook.com/1585255635148632',
#   'commenter_id': '100006770348232',
#   'commenter_url': None,
#   'commenter_name': 'Nora Rossi',
#   'commenter_meta': None,
#   'comment_text': 'Nora Rossi',
#   'comment_time': None,
#   'comment_image': 'https://media1.tenor.co/images/90b44a6dab0064c391aafa1f98745ebf/tenor.gif?itemid=14267640',
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584876181853244',
#   'comment_url': 'https://facebook.com/1584876181853244',
#   'commenter_id': '1436352840',
#   'commenter_url': None,
#   'commenter_name': 'Nuñez Daniel',
#   'commenter_meta': None,
#   'comment_text': 'Nuñez Daniel',
#   'comment_time': None,
#   'comment_image': 'https://media.tenor.co/images/cb41642a609f24807a35ceead99d2c70/tenor.gif',
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584843918523137',
#   'comment_url': 'https://facebook.com/1584843918523137',
#   'commenter_id': '1316246105',
#   'commenter_url': None,
#   'commenter_name': 'Maria Fernanda Torres',
#   'commenter_meta': None,
#   'comment_text': 'Maria Fernanda Torres',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584863355187860',
#   'comment_url': 'https://facebook.com/1584863355187860',
#   'commenter_id': '1306980338',
#   'commenter_url': None,
#   'commenter_name': 'Gladys Haydee Corbetto',
#   'commenter_meta': None,
#   'comment_text': 'Gladys Haydee Corbetto',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1585454831795379',
#   'comment_url': 'https://facebook.com/1585454831795379',
#   'commenter_id': '100002383804525',
#   'commenter_url': None,
#   'commenter_name': 'Myriam Ochoa',
#   'commenter_meta': None,
#   'comment_text': 'Myriam Ochoa',
#   'comment_time': None,
#   'comment_image': 'https://media1.tenor.co/images/28c2e402103a28170d6a4f04fdeb43b1/tenor.gif?itemid=12628636',
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584829095191286',
#   'comment_url': 'https://facebook.com/1584829095191286',
#   'commenter_id': '100003025108562',
#   'commenter_url': None,
#   'commenter_name': 'Emilce Bello',
#   'commenter_meta': None,
#   'comment_text': 'Emilce Bello',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1585569948450534',
#   'comment_url': 'https://facebook.com/1585569948450534',
#   'commenter_id': '1507737021',
#   'commenter_url': None,
#   'commenter_name': 'Monica Lupiani',
#   'commenter_meta': None,
#   'comment_text': '🤦🤦🤦',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1585697945104401',
#   'comment_url': 'https://facebook.com/1585697945104401',
#   'commenter_id': '1266234466',
#   'commenter_url': None,
#   'commenter_name': 'Adriana Maria Cagnoni',
#   'commenter_meta': None,
#   'comment_text': 'Adriana Maria Cagnoni',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584905288517000',
#   'comment_url': 'https://facebook.com/1584905288517000',
#   'commenter_id': '1499504015',
#   'commenter_url': None,
#   'commenter_name': 'Monyk AC',
#   'commenter_meta': None,
#   'comment_text': 'Se viene la segunda dosis 👏👏👏',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584879515186244',
#   'comment_url': 'https://facebook.com/1584879515186244',
#   'commenter_id': '1610580932',
#   'commenter_url': None,
#   'commenter_name': 'Nicolas Altamirano',
#   'commenter_meta': None,
#   'comment_text': 'Pau Altamirano',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1585186695155526',
#   'comment_url': 'https://facebook.com/1585186695155526',
#   'commenter_id': '100012542021478',
#   'commenter_url': None,
#   'commenter_name': 'Ofelia Ruiz',
#   'commenter_meta': None,
#   'comment_text': 'Sepa que las kakunas están matando a la gente y si no lo hacen quedan con secuelas graves',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584963128511216',
#   'comment_url': 'https://facebook.com/1584963128511216',
#   'commenter_id': '100002146543789',
#   'commenter_url': None,
#   'commenter_name': 'Susana Stefanazzi',
#   'commenter_meta': None,
#   'comment_text': 'Susana Stefanazzi',
#   'comment_time': None,
#   'comment_image': 'https://media1.giphy.com/media/Quylrk7rwhnVKa7ujx/giphy.gif?cid=120c0147lj60ocuawo1y5c4aup42mjq174a1pbkgfluodt7t&rid=giphy.gif',
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1587365098271019',
#   'comment_url': 'https://facebook.com/1587365098271019',
#   'commenter_id': '100001295156264',
#   'commenter_url': None,
#   'commenter_name': 'Adriana Sayago',
#   'commenter_meta': None,
#   'comment_text': 'Ojalá tuviera las dos dosis y lpqlp',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584829038524625',
#   'comment_url': 'https://facebook.com/1584829038524625',
#   'commenter_id': '100003025108562',
#   'commenter_url': None,
#   'commenter_name': 'Emilce Bello',
#   'commenter_meta': None,
#   'comment_text': 'Ajaaaaa',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1585499741790888',
#   'comment_url': 'https://facebook.com/1585499741790888',
#   'commenter_id': '100013442524957',
#   'commenter_url': None,
#   'commenter_name': 'Matilde Acosta',
#   'commenter_meta': None,
#   'comment_text': 'Matilde Acosta',
#   'comment_time': None,
#   'comment_image': 'https://media.tenor.co/images/c142fceefe3dd1afd6e64b6ebe4a9052/tenor.gif?t=AAXIIOWCOYAKrAcT6Qxz0g&itemid=4550434',
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1587115948295934',
#   'comment_url': 'https://facebook.com/1587115948295934',
#   'commenter_id': '100004113244429',
#   'commenter_url': None,
#   'commenter_name': 'Milda León',
#   'commenter_meta': None,
#   'comment_text': 'Jajajaja siiiii',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1586092671731595',
#   'comment_url': 'https://facebook.com/1586092671731595',
#   'commenter_id': '100002617680577',
#   'commenter_url': None,
#   'commenter_name': 'Claudia Chalin',
#   'commenter_meta': None,
#   'comment_text': 'Claudia Chalin',
#   'comment_time': None,
#   'comment_image': 'https://media.tenor.co/images/60fc32a3e51c7e23866608cfd588105c/tenor.gif?t=AAXACQlbo6AKStVP3A6fZQ&itemid=17906572',
#   '_post_id': '1584781958529333'},
#  {'comment_id': '1584805045193691',
#   'comment_url': 'https://facebook.com/1584805045193691',
#   'commenter_id': '100000064789114',
#   'commenter_url': None,
#   'commenter_name': 'Lorenzo Luis Lorenzo',
#   'commenter_meta': None,
#   'comment_text': 'La cepa Chinwenwencha, combinada con la Corruptus, seguro que generan un nuevo desastre .....',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1584781958529333'},
#  {'comment_id': '

#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590476281293234',
#   'comment_url': 'https://facebook.com/1590476281293234',
#   'commenter_id': '1157269564',
#   'commenter_url': None,
#   'commenter_name': 'Ana Maria',
#   'commenter_meta': None,
#   'comment_text': 'Bue, para que el que paga impuesto a la riqueza no gana el mínimo vital móvil ehhh. Y ese impuesto lo cobrar en varias partes del mundo y no es por única vez como acá debido a la pandemia y la deuda al FMI.',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590408454633350',
#   'comment_url': 'https://facebook.com/1590408454633350',
#   'commenter_id': '100000163593426',
#   'commenter_url': None,
#   'commenter_name': 'Anna Zelada',
#   'commenter_meta': None,
#   'comment_text': 'Me paso algo parecido hace unos años en mi ciudad natal.... me dijeron que por tener estudios tanto yo como una amiga no podían darnos la ayuda para armar una pyme (plata que te daban y devolvías en cuotas) .... que era x lo que fuimos y promocionaba el estado.\nQue para poder recibirlo tenía que haber tenido hijos, recibir una pensión o ser (perdón la palabra pero fue lo que me dijeron sin pelos en la lengua )"mogólica"... me quede helada me levante y me fuí del lugar sin saber que reacción tener frente a la oficina de recursos humanos de la municipalidad de mi ciudad que es kichnerista. Una vergüenza total.',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590421827965346',
#   'comment_url': 'https://facebook.com/1590421827965346',
#   'commenter_id': '515846220',
#   'commenter_url': None,
#   'commenter_name': 'Francisco Urioste',
#   'commenter_meta': None,
#   'comment_text': 'Y así en TODO el mundo donde el Socialismo haya puesto las garras',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590771884597007',
#   'comment_url': 'https://facebook.com/1590771884597007',
#   'commenter_id': '100053233944309',
#   'commenter_url': None,
#   'commenter_name': 'Carlos Sosa',
#   'commenter_meta': None,
#   'comment_text': 'Es mas rentable un plan descansar que producir y para colmo te deslomas laburando, pagas impuestos para pagarle al Brian la cerveza. A eso agrégale que tenés que aguantarte a los fracasados del gobierno de cada turno, que no tiene idea de lo que es invertir, producir. Parásitos que viven del estado o sea de mi o de vos. FRACASADOS que fundieron un país entero.',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590827704591425',
#   'comment_url': 'https://facebook.com/1590827704591425',
#   'commenter_id': '1547508245',
#   'commenter_url': None,
#   'commenter_name': 'Ema CA',
#   'commenter_meta': None,
#   'comment_text': 'HAY QUE IRSE AFUERA... Como sea, este pais no da para mas, ya ni estudiando y esforzándote llegas a algo en esta bosta de pais lleno de corrupción , delincuencia y vagancia...',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590431704631025',
#   'comment_url': 'https://facebook.com/1590431704631025',
#   'commenter_id': '100000274202050',
#   'commenter_url': None,
#   'commenter_name': 'Marcela Müller',
#   'commenter_meta': None,
#   'comment_text': 'El impuesto a las Ganancias lo va a tener que pagar aunque no le quede ninguna ganancia... Tristísimo.',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590419377965591',
#   'comment_url': 'https://facebook.com/1590419377965591',
#   'commenter_id': '640511838',
#   'commenter_url': None,
#   'commenter_name': 'Santi De Agostini',
#   'commenter_meta': None,
#   'comment_text': 'Tan cierto que duele! A eso súmale escuela privada, salud privada y seguridad privada. Por qué nada funciona bien. Pagamos impuestos al pedo!!!',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590428391298023',
#   'comment_url': 'https://facebook.com/1590428391298023',
#   'commenter_id': '100007960812075',
#   'commenter_url': None,
#   'commenter_name': 'Mariela Alonso',
#   'commenter_meta': None,
#   'comment_text': 'Cuanto cuesta querés trabajar en este país. Tan real y triste!!!!',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590849257922603',
#   'comment_url': 'https://facebook.com/1590849257922603',
#   'commenter_id': '1145350118',
#   'commenter_url': None,
#   'commenter_name': 'Mariana Carreras',
#   'commenter_meta': None,
#   'comment_text': 'Así es! Imposible progresar con éstos bastardos de gobernantes!!! Los únicos beneficiados son los que no trabajan y las que se dedican a tener cría, sin comparar con los animales!',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590405971300265',
#   'comment_url': 'https://facebook.com/1590405971300265',
#   'commenter_id': '100001701370851',
#   'commenter_url': None,
#   'commenter_name': 'Jimmy Adaro',
#   'commenter_meta': None,
#   'comment_text': 'Ojo que "hacerte rico" implica ganar más de US$ 1M por año. Argentina ex país...',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590954467912082',
#   'comment_url': 'https://facebook.com/1590954467912082',
#   'commenter_id': '100000507141738',
#   'commenter_url': None,
#   'commenter_name': 'Daniel Silva',
#   'commenter_meta': None,
#   'comment_text': 'que triste realidad,gracia\ns politicos , todos. que destruyeron al pais',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590434407964088',
#   'comment_url': 'https://facebook.com/1590434407964088',
#   'commenter_id': '100055905042097',
#   'commenter_url': None,
#   'commenter_name': 'José Maria Escobar',
#   'commenter_meta': None,
#   'comment_text': 'Que buen gobierno ,ESPECTACULAR,d\nespués hablamos de MACRI',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590492531291609',
#   'comment_url': 'https://facebook.com/1590492531291609',
#   'commenter_id': '724627052',
#   'commenter_url': None,
#   'commenter_name': 'Alejandra Fortunato',
#   'commenter_meta': None,
#   'comment_text': 'Que poca iniciativa e incentivo para una pyme en este país!!!! Que desgracia!!! Encima son las que dan trabajo!!! El problema es ese, que nadie quiere trabajar….',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590432281297634',
#   'comment_url': 'https://facebook.com/1590432281297634',
#   'commenter_id': '100009525815041',
#   'commenter_url': None,
#   'commenter_name': 'Lorena Vera',
#   'commenter_meta': None,
#   'comment_text': 'Tal cual ... Encima que querés trabajar te cobran diez mil impuestos y te piden cien mil requisitos...el\nmundo del revés',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590434494630746',
#   'comment_url': 'https://facebook.com/1590434494630746',
#   'commenter_id': '100001692858305',
#   'commenter_url': None,
#   'commenter_name': 'Marcela Gandulla',
#   'commenter_meta': None,
#   'comment_text': 'Ni hablar de las cuotas "sindicales"',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590430304631165',
#   'comment_url': 'https://facebook.com/1590430304631165',
#   'commenter_id': '1329724092',
#   'commenter_url': None,
#   'commenter_name': 'Ruben Prosperi',
#   'commenter_meta': None,
#   'comment_text': 'La triste realidad con el peor populismo peroncho de la historia',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590406007966928',
#   'comment_url': 'https://facebook.com/1590406007966928',
#   'commenter_id': '100028354294244',
#   'commenter_url': None,
#   'commenter_name': 'Lidia Pietraci',
#   'commenter_meta': None,
#   'comment_text': 'Muy cierto porque a mi me paso Increíble pero cierto, lamentable',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590438317963697',
#   'comment_url': 'https://facebook.com/1590438317963697',
#   'commenter_id': '100006369097753',
#   'commenter_url': None,
#   'commenter_name': 'Simón Ciro Amadeo Gerez',
#   'commenter_meta': None,
#   'comment_text': 'Rebelión fiscal... es la única que queda',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590417761299086',
#   'comment_url': 'https://facebook.com/1590417761299086',
#   'commenter_id': '100000595221325',
#   'commenter_url': None,
#   'commenter_name': 'Luis Balverde',
#   'commenter_meta': None,
#   'comment_text': 'Argentain peronia.',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590409091299953',
#   'comment_url': 'https://facebook.com/1590409091299953',
#   'commenter_id': '100057457422324',
#   'commenter_url': None,
#   'commenter_name': 'Ani Santillan',
#   'commenter_meta': None,
#   'comment_text': 'Ustedes también que quieren todo gratis',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1591881564486039',
#   'comment_url': 'https://facebook.com/1591881564486039',
#   'commenter_id': '100000968284163',
#   'commenter_url': None,
#   'commenter_name': 'Claudia Sviatskin',
#   'commenter_meta': None,
#   'comment_text': 'Se dan Cuenta Que Esté País Jamás. Jamás. Jamás. Va Crecer. Progresar y Dar Oportunidades A La Gente que Quieren Apostar a la Argentina??? Para que Carajo Tenemos Un Congreso Con Tantos Diputados. Senadores. Y Un Equipo Económico y Productivo cobrando sueldos Altísimos... Ahora que estamos en Campaña... Quienes Son Los que Proponen Reformas de Leyes??? Los escucharon? Quienes son???',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590442674629928',
#   'comment_url': 'https://facebook.com/1590442674629928',
#   'commenter_id': '100034711440688',
#   'commenter_url': None,
#   'commenter_name': 'Mariu Sand',
#   'commenter_meta': None,
#   'comment_text': 'El sistema está estrictamente echo para darle el 100% de las ganancias a los "de arriba" osea los políticos y presidente y a todos los que trabajan en la municipalidad y a todos sus familiares y conocidos.no al pueblo.ok.',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590441801296682',
#   'comment_url': 'https://facebook.com/1590441801296682',
#   'commenter_id': '100034775405026',
#   'commenter_url': None,
#   'commenter_name': 'Laura Correa',
#   'commenter_meta': None,
#   'comment_text': 'Se q aveces nos decimos q no podemos hacer nada..pero algo podemos hacer NO IR A VOTAR A NINGUNO ...seamos conscientes y responsables!!🙏🙏\nO si no vamos a tener q salir a las calles como en jujuy 💪',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590504551290407',
#   'comment_url': 'https://facebook.com/1590504551290407',
#   'commenter_id': '100003602125688',
#   'commenter_url': None,
#   'commenter_name': 'Marcela Rivero',
#   'commenter_meta': None,
#   'comment_text': 'El primero le asegura el voto, el segundo, no. Sencillo. En peronia estamos en bancarrota pero siguen sumando subsidios y planes. 🤮',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1591322341208628',
#   'comment_url': 'https://facebook.com/1591322341208628',
#   'commenter_id': '1242858507',
#   'commenter_url': None,
#   'commenter_name': 'Débora Chiama',
#   'commenter_meta': None,
#   'comment_text': 'En qué clase de País nos hemos convertido?',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590574024616793',
#   'comment_url': 'https://facebook.com/1590574024616793',
#   'commenter_id': '100000490707251',
#   'commenter_url': None,
#   'commenter_name': 'Marito Berrini',
#   'commenter_meta': None,
#   'comment_text': 'Si te queda ganancia impuesto a las ganancias? Ese te lo sacan siempre',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590505551290307',
#   'comment_url': 'https://facebook.com/1590505551290307',
#   'commenter_id': '1248682565',
#   'commenter_url': None,
#   'commenter_name': 'Mirtha Sosa',
#   'commenter_meta': None,
#   'comment_text': 'Yo ahí mismo le doy mi DNI y que me de un Plan!! (a la m... la PyME!!) JEJE',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1590437487963780',
#   'comment_url': 'https://facebook.com/1590437487963780',
#   'commenter_id': '100000621830643',
#   'commenter_url': None,
#   'commenter_name': 'Pimpo Leri',
#   'commenter_meta': None,
#   'comment_text': 'Es así, es la consecuencia de vivir en un país donde a quien gobierna solo le importa perpetuarse en el poder y para eso implementa planes sociales para algunos que representan potenciales votantes 🤡🎪🎡🎠',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'},
#  {'comment_id': '1592454154428780',
#   'comment_url': 'https://facebook.com/1592454154428780',
#   'commenter_id': '100016738277576',
#   'commenter_url': None,
#   'commenter_name': 'Angel Maimone',
#   'commenter_meta': None,
#   'comment_text': 'Triste realidad y faltó una\nTENES QUE TRABAJAR!!!!!!!\n!!!!',
#   'comment_time': None,
#   'comment_image': None,
#   '_post_id': '1590404371300425'}]

# %% [markdown]
# ## Posts
#
# original_request_url, post_url, post_id, text, post_text, time, image, images, images_lowquality, images_description, images_lowquality_description, likes, comments, shares, link, user_id	username, user_url, reactions, reaction_count
#
# ## Comments
#
# comment_id, comment_url, commenter_id, commenter_name, comment_text, comment_image, _post_id
#
# ## Replies
#
# comment_id, comment_url, commenter_id, commenter_name, comment_text, comment_time, comment_image, _comment_id

# %%
pd.DataFrame(posts)
# Out:
#    original_request_url                                           post_url  \
# 0      1584781918529337            https://m.facebook.com/1584781958529333
# 1      1590404371300425  https://facebook.com/story.php?story_fbid=1590...
#
#             post_id                  text             post_text shared_text  \
# 0  1584781958529333  Coherencia Por Favor  Coherencia Por Favor        None
# 1  1590404371300425                                                    None
#
#                  time                                              image  \
# 0 2021-07-26 00:00:00  https://scontent.faep9-1.fna.fbcdn.net/v/t1.64...
# 1 2021-08-03 18:12:25  https://scontent.faep9-2.fna.fbcdn.net/v/t1.64...
#
#                                     image_lowquality  \
# 0  https://scontent.faep9-1.fna.fbcdn.net/v/t1.64...
# 1  https://scontent.faep9-2.fna.fbcdn.net/v/t1.64...
#
#                                               images  ... shared_user_id  \
# 0  [https://scontent.faep9-1.fna.fbcdn.net/v/t1.6...  ...           None
# 1  [https://scontent.faep9-2.fna.fbcdn.net/v/t1.6...  ...           None
#
#   shared_username shared_post_url available reactors w3_fb_url reactions  \
# 0            None            None      True     None      None      None
# 1            None            None      True     None      None      None
#
#   reaction_count          image_id           image_ids
# 0           None               NaN                 NaN
# 1           None  1590404241300438  [1590404241300438]
#
# [2 rows x 43 columns]

# %%
pd.DataFrame(comments).comment_url.apply(lambda x: len(x)).max()
# Out:
# 37

# %%
, , commenter_id, commenter_name, comment_text, comment_image, _post_id

# %%
df = pd.DataFrame(posts)
for col in df.columns:
    print(col)
    print(df[col].apply(lambda x: len(str(x))).max())
# Out:
# original_request_url
# 16
# post_url
# 77
# post_id
# 16
# text
# 20
# post_text
# 20
# shared_text
# 4
# time
# 19
# image
# 257
# image_lowquality
# 257
# images
# 261
# images_description
# 525
# images_lowquality
# 261
# images_lowquality_description
# 525
# video
# 4
# video_duration_seconds
# 4
# video_height
# 4
# video_id
# 4
# video_quality
# 4
# video_size_MB
# 4
# video_thumbnail
# 4
# video_watches
# 4
# video_width
# 4
# likes
# 3
# comments
# 2
# shares
# 4
# link
# 89
# user_id
# 15
# username
# 20
# user_url
# 60
# is_live
# 5
# factcheck
# 4
# shared_post_id
# 4
# shared_time
# 4
# shared_user_id
# 4
# shared_username
# 4
# shared_post_url
# 4
# available
# 4
# reactors
# 4
# w3_fb_url
# 4
# reactions
# 4
# reaction_count
# 4
# image_id
# 16
# image_ids
# 20

# %%
df.iloc[:, :20]
# Out:
#    original_request_url                                           post_url  \
# 0      1584781918529337            https://m.facebook.com/1584781958529333
# 1      1590404371300425  https://facebook.com/story.php?story_fbid=1590...
#
#             post_id                  text             post_text shared_text  \
# 0  1584781958529333  Coherencia Por Favor  Coherencia Por Favor        None
# 1  1590404371300425                                                    None
#
#                  time                                              image  \
# 0 2021-07-26 00:00:00  https://scontent.faep9-1.fna.fbcdn.net/v/t1.64...
# 1 2021-08-03 18:12:25  https://scontent.faep9-2.fna.fbcdn.net/v/t1.64...
#
#                                     image_lowquality  \
# 0  https://scontent.faep9-1.fna.fbcdn.net/v/t1.64...
# 1  https://scontent.faep9-2.fna.fbcdn.net/v/t1.64...
#
#                                               images  \
# 0  [https://scontent.faep9-1.fna.fbcdn.net/v/t1.6...
# 1  [https://scontent.faep9-2.fna.fbcdn.net/v/t1.6...
#
#                                   images_description  \
# 0                                               None
# 1  [Puede ser una imagen de texto que dice "ANSES...
#
#                                    images_lowquality  \
# 0  [https://scontent.faep9-1.fna.fbcdn.net/v/t1.6...
# 1  [https://scontent.faep9-2.fna.fbcdn.net/v/t1.6...
#
#                        images_lowquality_description video  \
# 0  [Puede ser una imagen de texto que dice "Yo co...  None
# 1  [Puede ser una imagen de texto que dice "ANSES...  None
#
#   video_duration_seconds video_height video_id video_quality video_size_MB  \
# 0                   None         None     None          None          None
# 1                   None         None     None          None          None
#
#   video_thumbnail
# 0            None
# 1            None

# %%
df.isna().sum()
# Out:
# comment_id         0
# comment_url        0
# commenter_id       0
# commenter_url     51
# commenter_name     0
# commenter_meta    51
# comment_text       0
# comment_time      51
# comment_image     45
# _post_id           0
# dtype: int64

# %%
df
# Out:
#    original_request_url                                           post_url  \
# 0      1584781918529337            https://m.facebook.com/1584781958529333
# 1      1590404371300425  https://facebook.com/story.php?story_fbid=1590...
#
#             post_id                  text             post_text shared_text  \
# 0  1584781958529333  Coherencia Por Favor  Coherencia Por Favor        None
# 1  1590404371300425                                                    None
#
#                  time                                              image  \
# 0 2021-07-26 00:00:00  https://scontent.faep9-1.fna.fbcdn.net/v/t1.64...
# 1 2021-08-03 18:12:25  https://scontent.faep9-2.fna.fbcdn.net/v/t1.64...
#
#                                     image_lowquality  \
# 0  https://scontent.faep9-1.fna.fbcdn.net/v/t1.64...
# 1  https://scontent.faep9-2.fna.fbcdn.net/v/t1.64...
#
#                                               images  ... shared_user_id  \
# 0  [https://scontent.faep9-1.fna.fbcdn.net/v/t1.6...  ...           None
# 1  [https://scontent.faep9-2.fna.fbcdn.net/v/t1.6...  ...           None
#
#   shared_username shared_post_url available reactors w3_fb_url reactions  \
# 0            None            None      True     None      None      None
# 1            None            None      True     None      None      None
#
#   reaction_count          image_id           image_ids
# 0           None               NaN                 NaN
# 1           None  1590404241300438  [1590404241300438]
#
# [2 rows x 43 columns]

# %%
df.time
# Out:
# 0   2021-07-26 00:00:00
# 1   2021-08-03 18:12:25
# Name: time, dtype: datetime64[ns]

# %%
pd.DataFrame(comments)
# Out:
#           comment_id                            comment_url     commenter_id  \
# 50  1592454154428780  https://facebook.com/1592454154428780  100016738277576
#
#    commenter_url           commenter_name commenter_meta  \
# 0           None          Nestor Paladino           None
# 1           None          Analia Gabriela           None
# 2           None               Nora Rossi           None
# 3           None             Nuñez Daniel           None
# 4           None    Maria Fernanda Torres           None
# 5           None   Gladys Haydee Corbetto           None
# 6           None             Myriam Ochoa           None
# 7           None             Emilce Bello           None
# 8           None           Monica Lupiani           None
# 9           None    Adriana Maria Cagnoni           None
# 10          None                 Monyk AC           None
# 11          None       Nicolas Altamirano           None
# 12          None              Ofelia Ruiz           None
# 13          None        Susana Stefanazzi           None
# 14          None           Adriana Sayago           None
# 15          None             Emilce Bello           None
# 16          None           Matilde Acosta           None
# 17          None               Milda León           None
# 18          None           Claudia Chalin           None
# 19          None     Lorenzo Luis Lorenzo           None
# 20          None               Nahuel Niz           None
# 21          None               Liz Campos           None
# 22          None                Ana Maria           None
# 23          None              Anna Zelada           None
# 24          None        Francisco Urioste           None
# 25          None              Carlos Sosa           None
# 26          None                   Ema CA           None
# 27          None           Marcela Müller           None
# 28          None        Santi De Agostini           None
# 29          None           Mariela Alonso           None
# 30          None         Mariana Carreras           None
# 31          None              Jimmy Adaro           None
# 32          None             Daniel Silva           None
# 33          None       José Maria Escobar           None
# 34          None      Alejandra Fortunato           None
# 35          None              Lorena Vera           None
# 36          None         Marcela Gandulla           None
# 37          None           Ruben Prosperi           None
# 38          None           Lidia Pietraci           None
# 39          None  Simón Ciro Amadeo Gerez           None
# 40          None            Luis Balverde           None
# 41          None            Ani Santillan           None
# 42          None        Claudia Sviatskin           None
# 43          None               Mariu Sand           None
# 44          None             Laura Correa           None
# 45          None           Marcela Rivero           None
# 46          None            Débora Chiama           None
# 47          None           Marito Berrini           None
# 48          None              Mirtha Sosa           None
# 49          None               Pimpo Leri           None
# 50          None            Angel Maimone           None
#
#                                          comment_text comment_time  \
# 0                   ¿ Nueva "cepa Robin Hood" ..?🏹🤣🏹🤣         None
# 1                     La nueva cepa se llama Hawkeye.         None
# 2                                          Nora Rossi         None
# 3                                        Nuñez Daniel         None
# 4                               Maria Fernanda Torres         None
# 5                              Gladys Haydee Corbetto         None
# 6                                        Myriam Ochoa         None
# 7                                        Emilce Bello         None
# 8                                                 🤦🤦🤦         None
# 9                               Adriana Maria Cagnoni         None
# 10                      Se viene la segunda dosis 👏👏👏         None
# 11                                     Pau Altamirano         None
# 12  Sepa que las kakunas están matando a la gente ...         None
# 13                                  Susana Stefanazzi         None
# 14                Ojalá tuviera las dos dosis y lpqlp         None
# 15                                            Ajaaaaa         None
# 16                                     Matilde Acosta         None
# 17                                    Jajajaja siiiii         None
# 18                                     Claudia Chalin         None
# 19  La cepa Chinwenwencha, combinada con la Corrup...         None
# 20  El tilingo\nEn un artículo de la revista Confi...         None
# 21  Lamentablemente\npara el que labura esta todo ...         None
# 22  Bue, para que el que paga impuesto a la riquez...         None
# 23  Me paso algo parecido hace unos años en mi ciu...         None
# 24  Y así en TODO el mundo donde el Socialismo hay...         None
# 25  Es mas rentable un plan descansar que producir...         None
# 26  HAY QUE IRSE AFUERA... Como sea, este pais no ...         None
