# %%
from facebook_scraper import get_posts

# %% [markdown]
# group: group id, to scrape groups instead of pages. Default is None.
#
# pages: how many pages of posts to request, the first 2 pages may have no results, so try with a number greater than 2. Default is 10.
#
# timeout: how many seconds to wait before timing out. Default is 5.
#
# credentials: tuple of user and password to login before requesting the posts. Default is None.
#
# extra_info: bool, if true the function will try to do an extra request to get the post reactions. Default is False.
#
# youtube_dl: bool, use Youtube-DL for (high-quality) video extraction. You need to have youtube-dl installed on your
# environment. Default is False.
#
# post_urls: list, URLs or post IDs to extract posts from. Alternative to fetching based on username.
#
# cookies: One of:
# The path to a file containing cookies in Netscape or JSON format. You can extract cookies from your browser after logging into Facebook with an extension like EditThisCookie (Chrome) or Cookie Quick Manager (Firefox). Make sure that you include both the c_user cookie and the xs cookie, you will get an InvalidCookies exception if you don't.
# A CookieJar
# A dictionary that can be converted to a CookieJar with cookiejar_from_dict
#
# options: Dictionary of options. Set options={"comments": True} to extract comments, set options={"reactors": True} to extract the people reacting to the post. Both comments and reactors can also be set to a number to set a limit for the amount of comments/reactors to retrieve. The default limit for comments is 5000 and the default limit for reactors is 3000. Set options={"progress": True} to get a tqdm progress bar while extracting comments and replies. Set options={"allow_extra_requests": False} to disable making extra requests when extracting post data (required for some things like full text and image links). Set options={"posts_per_page": 200} to request 200 posts per page. The default is 4.

# %%
PAGE_NAME = 'coherenciaporfavor'

# %%
options = {'comments': True, 'progress': True, 'reactors': True}#, 'posts_per_page': 200}
#options = {}
comments = []

for post in get_posts(PAGE_NAME, 
                      pages=10, options=options):#, comments=True):
    print(post['text'])
    comments.append(post['comments_full'])
    
# override comments limit
# Out:
# /Users/tiaqui/Documents/Code/facebook_scraper/fb_scraper/lib/python3.9/site-packages/facebook_scraper/facebook_scraper.py:278: UserWarning: Locale detected as es_LA - for best results, set to en_US
#   warnings.warn(f"Locale detected as {locale} - for best results, set to en_US")
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# De Miguel Boggiano
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# Sigan a Germán Pugnaloni
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Gracias Josito.
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# De Miguel Boggiano
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# De Macarena Alifraco
# Cristian Angio
# Nada.respetan
# sigan a Miguel Boggiano
# Nada.respetan
# Gracias Innoligent
#
#
#
#
#
# De Adrián Puente
# Nostalgia!
# De Marcelo Fava.

# %%
post.keys()
# Out:
# dict_keys(['post_id', 'text', 'post_text', 'shared_text', 'time', 'image', 'image_lowquality', 'images', 'images_description', 'images_lowquality', 'images_lowquality_description', 'video', 'video_duration_seconds', 'video_height', 'video_id', 'video_quality', 'video_size_MB', 'video_thumbnail', 'video_watches', 'video_width', 'likes', 'comments', 'shares', 'post_url', 'link', 'user_id', 'username', 'user_url', 'is_live', 'factcheck', 'shared_post_id', 'shared_time', 'shared_user_id', 'shared_username', 'shared_post_url', 'available', 'comments_full', 'reactors', 'w3_fb_url', 'reactions', 'reaction_count', 'image_id', 'image_ids'])

# %%
post
# Out:
# {'post_id': '1588387128168816',
#  'text': 'De Marcelo Fava.',
#  'post_text': 'De Marcelo Fava.',
#  'shared_text': '',
#  'time': datetime.datetime(2021, 7, 31, 20, 39, 15),
#  'image': 'https://scontent.faep9-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/228547112_1588386978168831_5498550061224689673_n.jpg?_nc_cat=102&ccb=1-4&_nc_sid=110474&_nc_ohc=WR4Cyg1f2QkAX-aifWU&_nc_ht=scontent.faep9-1.fna&oh=3787d1e056b8b2ac170773f354634bf9&oe=613450C1',
#  'image_lowquality': 'https://scontent.faep9-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/228547112_1588386978168831_5498550061224689673_n.jpg?_nc_cat=102&ccb=1-4&_nc_sid=110474&_nc_ohc=WR4Cyg1f2QkAX-aifWU&_nc_ht=scontent.faep9-1.fna&oh=3787d1e056b8b2ac170773f354634bf9&oe=613450C1',
#  'images': ['https://scontent.faep9-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/228547112_1588386978168831_5498550061224689673_n.jpg?_nc_cat=102&ccb=1-4&_nc_sid=110474&_nc_ohc=WR4Cyg1f2QkAX-aifWU&_nc_ht=scontent.faep9-1.fna&oh=3787d1e056b8b2ac170773f354634bf9&oe=613450C1'],
#  'images_description': ['Puede ser una imagen de 1 persona y texto que dice "Fabiola tenía personal trainer y Delfina Pignatiello entrenó para las Olimpiadas en una pileta de 2x2. Coherencia por favor DELIS DEL PIGNATIELLO FBNATIELLO"'],
#  'images_lowquality': ['https://scontent.faep9-1.fna.fbcdn.net/v/t1.6435-9/fr/cp0/e15/q65/228547112_1588386978168831_5498550061224689673_n.jpg?_nc_cat=102&ccb=1-4&_nc_sid=110474&_nc_ohc=WR4Cyg1f2QkAX-aifWU&_nc_ht=scontent.faep9-1.fna&oh=3787d1e056b8b2ac170773f354634bf9&oe=613450C1'],
#  'images_lowquality_description': ['Puede ser una imagen de 1 persona y texto que dice "Fabiola tenía personal trainer y Delfina Pignatiello entrenó para las Olimpiadas en una pileta de 2x2. Coherencia por favor DELIS DEL PIGNATIELLO FBNATIELLO"'],
#  'video': None,
#  'video_duration_seconds': None,
#  'video_height': None,
#  'video_id': None,
#  'video_quality': None,
#  'video_size_MB': None,
#  'video_thumbnail': None,
#  'video_watches': None,
#  'video_width': None,
#  'likes': 0,
#  'comments': 0,
#  'shares': 0,
#  'post_url': 'https://facebook.com/coherenciaporfavor/posts/1588387128168816',
#  'link': None,
#  'user_id': '347304572277084',
#  'username': 'Coherencia Por Favor',
#  'user_url': 'https://facebook.com/coherenciaporfavor/?__tn__=C-R',
#  'is_live': False,
#  'factcheck': None,
#  'shared_post_id': None,
#  'shared_time': None,
#  'shared_user_id': None,
#  'shared_username': None,
#  'shared_post_url': None,
#  'available': True,
#  'comments_full': None,
#  'reactors': None,
#  'w3_fb_url': None,
#  'reactions': None,
#  'reaction_count': None,
#  'image_id': '1588386968168832',
#  'image_ids': ['1588386968168832']}

# %%
comments
# Out:
# [[{'comment_id': '1592626511078211',
#    'comment_url': 'https://facebook.com/1592626511078211',
#    'commenter_id': '1159323150',
#    'commenter_url': None,
#    'commenter_name': 'Alejandro J. Feres',
#    'commenter_meta': None,
#    'comment_text': 'Hasta Messi se quedó sin laburo con Alverso 😔',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 49, 28, 372362),
#    'comment_image': None},
#   {'comment_id': '1592618417745687',
#    'comment_url': 'https://facebook.com/1592618417745687',
#    'commenter_id': '100002617212749',
#    'commenter_url': None,
#    'commenter_name': 'Carmen Godoy',
#    'commenter_meta': None,
#    'comment_text': 'Falto escribir en Argentina 😂😂😂',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 31, 28, 381729),
#    'comment_image': None},
#   {'comment_id': '1592607947746734',
#    'comment_url': 'https://facebook.com/1592607947746734',
#    'commenter_id': '100000654007148',
#    'commenter_url': None,
#    'commenter_name': 'Magui Nuñez',
#    'commenter_meta': None,
#    'comment_text': 'Capaz en Sacachispas lo contraten...😅',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 28, 386993),
#    'comment_image': None},
#   {'comment_id': '1592614347746094',
#    'comment_url': 'https://facebook.com/1592614347746094',
#    'commenter_id': '100012881385234',
#    'commenter_url': None,
#    'commenter_name': 'Alfredo Gonzalez',
#    'commenter_meta': None,
#    'comment_text': 'ANTECEDENTES?, 700 GOLES , 35 TÍTULOS, 6 BALONES DE ORO, Y SOY ARGENTINO, ETCÉTERA.....',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 21, 28, 391570),
#    'comment_image': None},
#   {'comment_id': '1592605481080314',
#    'comment_url': 'https://facebook.com/1592605481080314',
#    'commenter_id': '100006593325915',
#    'commenter_url': None,
#    'commenter_name': 'Adriana Martinez',
#    'commenter_meta': None,
#    'comment_text': 'Hasta q cobre el fondo de desempleo. Goles a demanda 🤣🤣🤣🤣🤣',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 28, 396099),
#    'comment_image': None},
#   {'comment_id': '1592611924413003',
#    'comment_url': 'https://facebook.com/1592611924413003',
#    'commenter_id': '100009617022697',
#    'commenter_url': None,
#    'commenter_name': 'Ruben Arena',
#    'commenter_meta': None,
#    'comment_text': 'Y que goles ¡¡¡ los mejores ¡¡¡',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 14, 28, 400243),
#    'comment_image': None},
#   {'comment_id': '1592612321079630',
#    'comment_url': 'https://facebook.com/1592612321079630',
#    'commenter_id': '100000989941906',
#    'commenter_url': None,
#    'commenter_name': 'Daniel Telesca',
#    'commenter_meta': None,
#    'comment_text': 'Debería poner hacen sin h, y le dan un plan!',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 15, 28, 405467),
#    'comment_image': None},
#   {'comment_id': '1592614697746059',
#    'comment_url': 'https://facebook.com/1592614697746059',
#    'commenter_id': '100025460029917',
#    'commenter_url': None,
#    'commenter_name': 'Graciela Wybert',
#    'commenter_meta': None,
#    'comment_text': 'Tiene TRABAJO y LIBERTAD en Francia.toma .que queres que coma polenta.?😂🇦🇷',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 22, 28, 411358),
#    'comment_image': None},
#   {'comment_id': '1592614414412754',
#    'comment_url': 'https://facebook.com/1592614414412754',
#    'commenter_id': '100033113047229',
#    'commenter_url': None,
#    'commenter_name': 'Eduardo',
#    'commenter_meta': None,
#    'comment_text': 'Un ejemplo lo felicito 😭😭😭😭😭😭😭😭',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 21, 28, 417657),
#    'comment_image': None},
#   {'comment_id': '1592614114412784',
#    'comment_url': 'https://facebook.com/1592614114412784',
#    'commenter_id': '100001884920370',
#    'commenter_url': None,
#    'commenter_name': 'Claudio Romero',
#    'commenter_meta': None,
#    'comment_text': 'Vos tranquilo que yo nervioso pulga!!!',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 20, 28, 423058),
#    'comment_image': None},
#   {'comment_id': '1592625887744940',
#    'comment_url': 'https://facebook.com/1592625887744940',
#    'commenter_id': '100003746679041',
#    'commenter_url': None,
#    'commenter_name': 'Lidia Pallero',
#    'commenter_meta': None,
#    'comment_text': '¡¡¡ Esta sin trabajo !!!',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 47, 28, 427749),
#    'comment_image': None},
#   {'comment_id': '1592607984413397',
#    'comment_url': 'https://facebook.com/1592607984413397',
#    'commenter_id': '100028354294244',
#    'commenter_url': None,
#    'commenter_name': 'Lidia Pietraci',
#    'commenter_meta': None,
#    'comment_text': 'Que divino y es santafesino como yo',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 28, 432180),
#    'comment_image': None},
#   {'comment_id': '1592603917747137',
#    'comment_url': 'https://facebook.com/1592603917747137',
#    'commenter_id': '1012324608',
#    'commenter_url': None,
#    'commenter_name': 'Damian Fredy Gonzalez',
#    'commenter_meta': None,
#    'comment_text': 'Se pechean finales',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 28, 436673),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592633877744141',
#      'comment_url': 'https://facebook.com/1592633877744141',
#      'commenter_id': '757174786',
#      'commenter_url': None,
#      'commenter_name': 'Diego Ramos',
#      'commenter_meta': None,
#      'comment_text': 'Vos que ganaste reverendo idiota',
#      'comment_time': datetime.datetime(2021, 8, 6, 22, 5, 28, 815525),
#      'comment_image': None}]},
#   {'comment_id': '1592618851078977',
#    'comment_url': 'https://facebook.com/1592618851078977',
#    'commenter_id': '100033113047229',
#    'commenter_url': None,
#    'commenter_name': 'Eduardo',
#    'commenter_meta': None,
#    'comment_text': 'Qué se venga acá 😁😁😁😁😁 i',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 33, 28, 822160),
#    'comment_image': None},
#   {'comment_id': '1592625571078305',
#    'comment_url': 'https://facebook.com/1592625571078305',
#    'commenter_id': '1396223412',
#    'commenter_url': None,
#    'commenter_name': 'Marcelo Settimo',
#    'commenter_meta': None,
#    'comment_text': 'Que Alguien le avise del AHORA 30 y la chequera santa fe',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 46, 28, 829465),
#    'comment_image': None},
#   {'comment_id': '1592634137744115',
#    'comment_url': 'https://facebook.com/1592634137744115',
#    'commenter_id': '1836574857',
#    'commenter_url': None,
#    'commenter_name': 'Patricia Gamboa',
#    'commenter_meta': None,
#    'comment_text': 'Patricia Gamboa',
#    'comment_time': datetime.datetime(2021, 8, 6, 22, 6, 28, 834938),
#    'comment_image': None},
#   {'comment_id': '1592628057744723',
#    'comment_url': 'https://facebook.com/1592628057744723',
#    'commenter_id': '100013563497723',
#    'commenter_url': None,
#    'commenter_name': 'Stella Maris',
#    'commenter_meta': None,
#    'comment_text': 'I ❤️ you',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 52, 28, 840750),
#    'comment_image': None},
#   {'comment_id': '1592619084412287',
#    'comment_url': 'https://facebook.com/1592619084412287',
#    'commenter_id': '100004035252452',
#    'commenter_url': None,
#    'commenter_name': 'Sabrina Delgado',
#    'commenter_meta': None,
#    'comment_text': 'Cómo joden , a quien le importa lo que haga???',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 33, 28, 844729),
#    'comment_image': None},
#   {'comment_id': '1592604854413710',
#    'comment_url': 'https://facebook.com/1592604854413710',
#    'commenter_id': '100007695673619',
#    'commenter_url': None,
#    'commenter_name': 'Silvia Alejandra Clifford',
#    'commenter_meta': None,
#    'comment_text': 'Silvia Alejandra Clifford',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 28, 849429),
#    'comment_image': 'https://media4.giphy.com/media/v1.Y2lkPTEyMGMwMTQ3MW80enE3bGZlZ2dpejlvNjljNmN4cWFmMXU4OHVxcjlwMmxsM2NjZSZjdD1n/sdFFBY3b4YNk49aFTs/giphy.gif'},
#   {'comment_id': '1592619307745598',
#    'comment_url': 'https://facebook.com/1592619307745598',
#    'commenter_id': '100033113047229',
#    'commenter_url': None,
#    'commenter_name': 'Eduardo',
#    'commenter_meta': None,
#    'comment_text': 'Jajajaja',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 34, 28, 854208),
#    'comment_image': None},
#   {'comment_id': '1592603791080483',
#    'comment_url': 'https://facebook.com/1592603791080483',
#    'commenter_id': '100008847972530',
#    'commenter_url': None,
#    'commenter_name': 'Edith E Vazquez',
#    'commenter_meta': None,
#    'comment_text': '👏👏👏👏👏',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 28, 858681),
#    'comment_image': None},
#   {'comment_id': '1592628171078045',
#    'comment_url': 'https://facebook.com/1592628171078045',
#    'commenter_id': '100004130988344',
#    'commenter_url': None,
#    'commenter_name': 'Gabriel Leguizamon',
#    'commenter_meta': None,
#    'comment_text': 'Se vende humos',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 52, 28, 862791),
#    'comment_image': None},
#   {'comment_id': '1592614754412720',
#    'comment_url': 'https://facebook.com/1592614754412720',
#    'commenter_id': '100000596682228',
#    'commenter_url': None,
#    'commenter_name': 'José Maria Gerstner',
#    'commenter_meta': None,
#    'comment_text': 'Se hacen goles, lastima q no tiene a nadie q le regale la pelota, idiot',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 22, 28, 867184),
#    'comment_image': None},
#   {'comment_id': '1592605207747008',
#    'comment_url': 'https://facebook.com/1592605207747008',
#    'commenter_id': '100001310476663',
#    'commenter_url': None,
#    'commenter_name': 'Max Caliba',
#    'commenter_meta': None,
#    'comment_text': 'HDP en la selección no hacías nada',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 28, 871545),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592634034410792',
#      'comment_url': 'https://facebook.com/1592634034410792',
#      'commenter_id': '757174786',
#      'commenter_url': None,
#      'commenter_name': 'Diego Ramos',
#      'commenter_meta': None,
#      'comment_text': 'Vos que hiciste muerto de hambre',
#      'comment_time': datetime.datetime(2021, 8, 6, 22, 5, 29, 480597),
#      'comment_image': None}]},
#   {'comment_id': '1592615964412599',
#    'comment_url': 'https://facebook.com/1592615964412599',
#    'commenter_id': '100000079311507',
#    'commenter_url': None,
#    'commenter_name': 'Pedro Martinez',
#    'commenter_meta': None,
#    'comment_text': 'Lo cagó al Barza, lo cagó al Kun que se quiere cortar las pelotas. Ídolo mechi evasor 🤣🤣🤷\u200d♂️',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 25, 29, 487014),
#    'comment_image': None},
#   {'comment_id': '1592622697745259',
#    'comment_url': 'https://facebook.com/1592622697745259',
#    'commenter_id': '100000325109066',
#    'commenter_url': None,
#    'commenter_name': 'La Pety Ag',
#    'commenter_meta': None,
#    'comment_text': 'Pagados no por el amor a su camiseta',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 43, 29, 494718),
#    'comment_image': None},
#   {'comment_id': '1592605201080342',
#    'comment_url': 'https://facebook.com/1592605201080342',
#    'commenter_id': '100002752340846',
#    'commenter_url': None,
#    'commenter_name': 'Francisco Blanco',
#    'commenter_meta': None,
#    'comment_text': 'El jueke 100 millones para vos.',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 29, 499923),
#    'comment_image': None},
#   {'comment_id': '1592618994412296',
#    'comment_url': 'https://facebook.com/1592618994412296',
#    'commenter_id': '100002901471232',
#    'commenter_url': None,
#    'commenter_name': 'Daniel Mendoza',
#    'commenter_meta': None,
#    'comment_text': 'Promoción no valida para Argentina.🤔',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 33, 29, 505798),
#    'comment_image': None},
#   {'comment_id': '1592613867746142',
#    'comment_url': 'https://facebook.com/1592613867746142',
#    'commenter_id': '100023397246112',
#    'commenter_url': None,
#    'commenter_name': 'Francisco Gonzalez Ambrosi',
#    'commenter_meta': None,
#    'comment_text': 'Entro al PSG',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 20, 29, 510125),
#    'comment_image': None},
#   {'comment_id': '1592616514412544',
#    'comment_url': 'https://facebook.com/1592616514412544',
#    'commenter_id': '100033113047229',
#    'commenter_url': None,
#    'commenter_name': 'Eduardo',
#    'commenter_meta': None,
#    'comment_text': 'Ni cerrando los ojos nos podemos imaginar ,,,, si todos los herederos dejan de trabajar hasta los tratará nietos comen sin mover un dedo y queda mucho más 😁',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 26, 29, 514945),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592628571078005',
#      'comment_url': 'https://facebook.com/1592628571078005',
#      'commenter_id': '100010163376304',
#      'commenter_url': None,
#      'commenter_name': 'Carina Pereyra',
#      'commenter_meta': None,
#      'comment_text': 'Eduardo Tal cual',
#      'comment_time': datetime.datetime(2021, 8, 6, 21, 53, 29, 942123),
#      'comment_image': None},
#     {'comment_id': '1592629374411258',
#      'comment_url': 'https://facebook.com/1592629374411258',
#      'commenter_id': '100033113047229',
#      'commenter_url': None,
#      'commenter_name': 'Eduardo',
#      'commenter_meta': None,
#      'comment_text': 'Carina Pereyra viva central 👌',
#      'comment_time': datetime.datetime(2021, 8, 6, 21, 55, 29, 947445),
#      'comment_image': None}]}],
#  [{'comment_id': '1592582114415984',
#    'comment_url': 'https://facebook.com/1592582114415984',
#    'commenter_id': '1343885296',
#    'commenter_url': None,
#    'commenter_name': 'Erika Flores',
#    'commenter_meta': None,
#    'comment_text': 'Frutillas con crema 🤩 mate 🧉 y pizza 🍕 fría 😋',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 34, 759888),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592634681077394',
#      'comment_url': 'https://facebook.com/1592634681077394',
#      'commenter_id': '100002452513342',
#      'commenter_url': None,
#      'commenter_name': 'Marcelo Flores',
#      'commenter_meta': None,
#      'comment_text': '20 megas mas canales HD xddddd',
#      'comment_time': datetime.datetime(2021, 8, 6, 22, 6, 35, 110818),
#      'comment_image': None}]},
#   {'comment_id': '1592627547744774',
#    'comment_url': 'https://facebook.com/1592627547744774',
#    'commenter_id': '100004235772968',
#    'commenter_url': None,
#    'commenter_name': 'Vanesa Mansilla',
#    'commenter_meta': None,
#    'comment_text': 'Me gustó más lo dulce 😂😂🤪',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 51, 35, 115823),
#    'comment_image': None},
#   {'comment_id': '1592629834411212',
#    'comment_url': 'https://facebook.com/1592629834411212',
#    'commenter_id': '100011225802016',
#    'commenter_url': None,
#    'commenter_name': 'Silvia Morales',
#    'commenter_meta': None,
#    'comment_text': 'Como nos empomaron , en todo, si sabian , que combinando vacunas , porque no se hiso antes y hubieran evitado , tantos enfermos y muertos , porque???Inutil\nes y pero caraduras y corruptos , para hacer negocios para ellos , hasta con la salud del Pueblo, no tienen perdon , ineficientes y cara rotas .',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 56, 35, 123413),
#    'comment_image': None},
#   {'comment_id': '1592577257749803',
#    'comment_url': 'https://facebook.com/1592577257749803',
#    'commenter_id': '100003177532507',
#    'commenter_url': None,
#    'commenter_name': 'Veinte Corazones',
#    'commenter_meta': None,
#    'comment_text': 'Mejor que nos pongan de segunda la antirrábica,par\na parar toda la rabia que tenemos.Caradur\nas!!!!!!!',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 128838),
#    'comment_image': None},
#   {'comment_id': '1592597334414462',
#    'comment_url': 'https://facebook.com/1592597334414462',
#    'commenter_id': '100033080921720',
#    'commenter_url': None,
#    'commenter_name': 'Jorge Castex',
#    'commenter_meta': None,
#    'comment_text': 'Y nos reimos de la propia desgracia.\nAsi nos va…',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 133406),
#    'comment_image': None},
#   {'comment_id': '1592604611080401',
#    'comment_url': 'https://facebook.com/1592604611080401',
#    'commenter_id': '100002503956507',
#    'commenter_url': None,
#    'commenter_name': 'Fernando David Bazán',
#    'commenter_meta': None,
#    'comment_text': 'Sacco y Vanzetti, Laurel & Hardy, chasman y chirolita, la mar en coche 🤣',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 138906),
#    'comment_image': None},
#   {'comment_id': '1592598324414363',
#    'comment_url': 'https://facebook.com/1592598324414363',
#    'commenter_id': '100000899778771',
#    'commenter_url': None,
#    'commenter_name': 'Emma Cristina Toledo',
#    'commenter_meta': None,
#    'comment_text': 'Y con caña con ruda ojo eh 🤦🏻\u200d♀️🤣🤣🤣',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 143382),
#    'comment_image': None},
#   {'comment_id': '1592605844413611',
#    'comment_url': 'https://facebook.com/1592605844413611',
#    'commenter_id': '100011467194147',
#    'commenter_url': None,
#    'commenter_name': 'Betty Martin',
#    'commenter_meta': None,
#    'comment_text': 'Nada de conejillo de indias.',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 147335),
#    'comment_image': None},
#   {'comment_id': '1592599797747549',
#    'comment_url': 'https://facebook.com/1592599797747549',
#    'commenter_id': '100009771549084',
#    'commenter_url': None,
#    'commenter_name': 'Liliana de Iriarte',
#    'commenter_meta': None,
#    'comment_text': 'Yo siempre pido granizado y cereza a la panna',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 151235),
#    'comment_image': None},
#   {'comment_id': '1592581797749349',
#    'comment_url': 'https://facebook.com/1592581797749349',
#    'commenter_id': '1065270220',
#    'commenter_url': None,
#    'commenter_name': 'Pablo Galeano',
#    'commenter_meta': None,
#    'comment_text': 'Coca y Fernet no?',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 155828),
#    'comment_image': None},
#   {'comment_id': '1592582307749298',
#    'comment_url': 'https://facebook.com/1592582307749298',
#    'commenter_id': '513719724',
#    'commenter_url': None,
#    'commenter_name': 'Daiana Mariel Velcott',
#    'commenter_meta': None,
#    'comment_text': 'Quesito y batata... 🤤🤤🤤',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 160249),
#    'comment_image': None},
#   {'comment_id': '1592575791083283',
#    'comment_url': 'https://facebook.com/1592575791083283',
#    'commenter_id': '1384515453',
#    'commenter_url': None,
#    'commenter_name': 'Vivian Balcarce',
#    'commenter_meta': None,
#    'comment_text': 'Mascarpone con frutos rojos!!! 🍓🍒🤷\u200d♀️',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 164522),
#    'comment_image': None},
#   {'comment_id': '1592587901082072',
#    'comment_url': 'https://facebook.com/1592587901082072',
#    'commenter_id': '1497861864',
#    'commenter_url': None,
#    'commenter_name': 'Susy Andrade',
#    'commenter_meta': None,
#    'comment_text': 'A falta de pan, buenas son las tortas diría mi vieja jajaja.\nReír para no llorar🙈',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 168569),
#    'comment_image': None},
#   {'comment_id': '1592583074415888',
#    'comment_url': 'https://facebook.com/1592583074415888',
#    'commenter_id': '100002371444314',
#    'commenter_url': None,
#    'commenter_name': 'Andrea Pappalardo',
#    'commenter_meta': None,
#    'comment_text': '2 e pollo 1 de choclo 3 de carne 1 de choclo 2 de pollo 🤣🤣',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 172556),
#    'comment_image': None},
#   {'comment_id': '1592620864412109',
#    'comment_url': 'https://facebook.com/1592620864412109',
#    'commenter_id': '100058844562198',
#    'commenter_url': None,
#    'commenter_name': 'Ana Lia Albiero Gomez',
#    'commenter_meta': None,
#    'comment_text': 'Coca con Fernet',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 37, 35, 176672),
#    'comment_image': None},
#   {'comment_id': '1592589294415266',
#    'comment_url': 'https://facebook.com/1592589294415266',
#    'commenter_id': '100000865934995',
#    'commenter_url': None,
#    'commenter_name': 'Laura Martinez',
#    'commenter_meta': None,
#    'comment_text': 'No doy más.',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 180502),
#    'comment_image': 'https://media1.tenor.co/images/28c2e402103a28170d6a4f04fdeb43b1/tenor.gif?itemid=12628636'},
#   {'comment_id': '1592594094414786',
#    'comment_url': 'https://facebook.com/1592594094414786',
#    'commenter_id': '100004484493171',
#    'commenter_url': None,
#    'commenter_name': 'Alexis Eduardo Moschen',
#    'commenter_meta': None,
#    'comment_text': 'chocolate con limon...va como piña...astra sinopharm',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 183828),
#    'comment_image': None},
#   {'comment_id': '1592598227747706',
#    'comment_url': 'https://facebook.com/1592598227747706',
#    'commenter_id': '100007695673619',
#    'commenter_url': None,
#    'commenter_name': 'Silvia Alejandra Clifford',
#    'commenter_meta': None,
#    'comment_text': 'Sputnik con caramelos media hora 😁',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 187774),
#    'comment_image': None},
#   {'comment_id': '1592589821081880',
#    'comment_url': 'https://facebook.com/1592589821081880',
#    'commenter_id': '100003559858148',
#    'commenter_url': None,
#    'commenter_name': 'Raquel Araya',
#    'commenter_meta': None,
#    'comment_text': 'Es para llorar pero no se si me tocan los frutos',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 191524),
#    'comment_image': None},
#   {'comment_id': '1592618121079050',
#    'comment_url': 'https://facebook.com/1592618121079050',
#    'commenter_id': '100001720810084',
#    'commenter_url': None,
#    'commenter_name': 'Domingo José Germinario',
#    'commenter_meta': None,
#    'comment_text': 'Sigo en la misma!! Un capo coherencia"',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 30, 35, 195547),
#    'comment_image': None},
#   {'comment_id': '1592574257750103',
#    'comment_url': 'https://facebook.com/1592574257750103',
#    'commenter_id': '1002580926',
#    'commenter_url': None,
#    'commenter_name': 'Elsa Marandino',
#    'commenter_meta': None,
#    'comment_text': 'realmente el que piensa todo esto es un genio',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 199524),
#    'comment_image': None},
#   {'comment_id': '1592596801081182',
#    'comment_url': 'https://facebook.com/1592596801081182',
#    'commenter_id': '100005928790622',
#    'commenter_url': None,
#    'commenter_name': 'Maria Gloria Ciuffo',
#    'commenter_meta': None,
#    'comment_text': 'Ivermectina + agua 🤭🤣🤣',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 203532),
#    'comment_image': None},
#   {'comment_id': '1592596194414576',
#    'comment_url': 'https://facebook.com/1592596194414576',
#    'commenter_id': '100001936079060',
#    'commenter_url': None,
#    'commenter_name': 'Monica Torres',
#    'commenter_meta': None,
#    'comment_text': 'Son impresentables estos "científicos "',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 206906),
#    'comment_image': None},
#   {'comment_id': '1592576637749865',
#    'comment_url': 'https://facebook.com/1592576637749865',
#    'commenter_id': '100011188007563',
#    'commenter_url': None,
#    'commenter_name': 'Liliana Mansilla Salva',
#    'commenter_meta': None,
#    'comment_text': 'No vale, yo quiero salame con pastelera.',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 211025),
#    'comment_image': None},
#   {'comment_id': '1592609227746606',
#    'comment_url': 'https://facebook.com/1592609227746606',
#    'commenter_id': '100002900926787',
#    'commenter_url': None,
#    'commenter_name': 'Claudia Veronica Acosta',
#    'commenter_meta': None,
#    'comment_text': 'Alcoyana alcoyana 🤭🤣🤣',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 215598),
#    'comment_image': None},
#   {'comment_id': '1592585071082355',
#    'comment_url': 'https://facebook.com/1592585071082355',
#    'commenter_id': '100008615555552',
#    'commenter_url': None,
#    'commenter_name': 'Diego Ur',
#    'commenter_meta': None,
#    'comment_text': 'y para los celiacos ???',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 219010),
#    'comment_image': None},
#   {'comment_id': '1592579431082919',
#    'comment_url': 'https://facebook.com/1592579431082919',
#    'commenter_id': '100001348966003',
#    'commenter_url': None,
#    'commenter_name': 'Pedro Pablo Fernandez',
#    'commenter_meta': None,
#    'comment_text': 'vidal donde haya un huequito...',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 35, 225543),
#    'comment_image': None},
#   {'comment_id': '1592605611080301',
#    'comment_url': 'https://facebook.com/1592605611080301',
#    'commenter_id': '100009178127812',
#    'commenter_url': None,
#    'commenter_name': 'Cecilia Margarita',
#    'commenter_meta': None,
#    'comment_text': 'Yo prefiero máscarpone con frutos Rojo',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 230555),
#    'comment_image': None},
#   {'comment_id': '1592594301081432',
#    'comment_url': 'https://facebook.com/1592594301081432',
#    'commenter_id': '100016152331040',
#    'commenter_url': None,
#    'commenter_name': 'Norma Beatriz Rodriguez',
#    'commenter_meta': None,
#    'comment_text': 'Son de terror estos 💩💩',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 10, 35, 234981),
#    'comment_image': None},
#   {'comment_id': '1592632797744249',
#    'comment_url': 'https://facebook.com/1592632797744249',
#    'commenter_id': '100010654173165',
#    'commenter_url': None,
#    'commenter_name': 'Jorge Doukatas',
#    'commenter_meta': None,
#    'comment_text': 'Mezclar Macri con Larreta te da .iwrda',
#    'comment_time': datetime.datetime(2021, 8, 6, 22, 2, 35, 240510),
#    'comment_image': None}],
#  [{'comment_id': '1592632991077563',
#    'comment_url': 'https://facebook.com/1592632991077563',
#    'commenter_id': '100000616387427',
#    'commenter_url': None,
#    'commenter_name': 'Victoria Llanos',
#    'commenter_meta': None,
#    'comment_text': 'Más bien de centenials, los millenials ya estamos grandecitos para semejante teatro...',
#    'comment_time': datetime.datetime(2021, 8, 6, 22, 3, 40, 52309),
#    'comment_image': None},
#   {'comment_id': '1592518381089024',
#    'comment_url': 'https://facebook.com/1592518381089024',
#    'commenter_id': '1310904587',
#    'commenter_url': None,
#    'commenter_name': 'Javier Pajón',
#    'commenter_meta': None,
#    'comment_text': 'Adultos también están igual....',
#    'comment_time': datetime.datetime(2021, 8, 6, 18, 10, 40, 60070),
#    'comment_image': None},
#   {'comment_id': '1592611717746357',
#    'comment_url': 'https://facebook.com/1592611717746357',
#    'commenter_id': '517882724',
#    'commenter_url': None,
#    'commenter_name': 'Pablo Rodriguez Mazzan Zigaran Segotta',
#    'commenter_meta': None,
#    'comment_text': 'Muchos entran llorando a los vacunatorios. Y eso que los políticos nos vienen vacunado hace años. Pero muchos todavía no se acostumbran.',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 14, 40, 66624),
#    'comment_image': None},
#   {'comment_id': '1592565934417602',
#    'comment_url': 'https://facebook.com/1592565934417602',
#    'commenter_id': '100007681994426',
#    'commenter_url': None,
#    'commenter_name': 'Sebastián Bordón',
#    'commenter_meta': None,
#    'comment_text': 'Centenials en todo caso.\nPD. Cuando querés hacer humor "inteligente" y no cazas una jajajaj',
#    'comment_time': datetime.datetime(2021, 8, 6, 20, 10, 40, 71298),
#    'comment_image': None},
#   {'comment_id': '1592508027756726',
#    'comment_url': 'https://facebook.com/1592508027756726',
#    'commenter_id': '100039523548928',
#    'commenter_url': None,
#    'commenter_name': 'Dipiro Dipiro',
#    'commenter_meta': None,
#    'comment_text': 'No entiendo 🤔🤔',
#    'comment_time': datetime.datetime(2021, 8, 6, 17, 10, 40, 75838),
#    'comment_image': None},
#   {'comment_id': '1592611151079747',
#    'comment_url': 'https://facebook.com/1592611151079747',
#    'commenter_id': '100025376295401',
#    'commenter_url': None,
#    'commenter_name': 'Patricio Gaitan',
#    'commenter_meta': None,
#    'comment_text': '😂😂 nada q ver..',
#    'comment_time': datetime.datetime(2021, 8, 6, 21, 12, 40, 82458),
#    'comment_image': None},
#   {'comment_id': '1592529941087868',
#    'comment_url': 'https://facebook.com/1592529941087868',
#    'commenter_id': '1128924956',
#    'commenter_url': None,
#    'commenter_name': 'Veronica Isakow',
#    'commenter_meta': None,
#    'comment_text': 'Y 5 días en cama después, x las dudas. 🙄',
#    'comment_time': datetime.datetime(2021, 8, 6, 18, 10, 40, 87498),
#    'comment_image': None},
#   {'comment_id': '1592548101086052',
#    'comment_url': 'https://facebook.com/1592548101086052',
#    'commenter_id': '1529576315',
#    'commenter_url': None,
#    'commenter_name': 'Nahuel SkaMorza',
#    'commenter_meta': None,
#    'comment_text': 'Centenials serían salames!',
#    'comment_time': datetime.datetime(2021, 8, 6, 19, 10, 40, 92111),
#    'comment_image': None},
#   {'comment_id': '1592542151086647',
#    'comment_url': 'https://facebook.com/1592542151086647',
#    'commenter_id': '100001684170232',
#    'commenter_url': None,
#    'commenter_name': 'Hugo Tordoni',
#    'commenter_meta': None,
#    'comment_text': 'Neymar style',
#    'comment_time': datetime.datetime(2021, 8, 6, 19, 10, 40, 96563),
#    'comment_image': None},
#   {'comment_id': '1592541197753409',
#    'comment_url': 'https://facebook.com/1592541197753409',
#    'commenter_id': '1408479322',
#    'commenter_url': None,
#    'commenter_name': 'Gonzalo Sebastián',
#    'commenter_meta': None,
#    'comment_text': 'Aprendan a usar la palabra millenials... ya q esa generación termino con los nacidos en 1996. Media pila!',
#    'comment_time': datetime.datetime(2021, 8, 6, 19, 10, 40, 102444),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592635014410694',
#      'comment_url': 'https://facebook.com/1592635014410694',
#      'commenter_id': '100000616387427',
#      'commenter_url': None,
#      'commenter_name': 'Victoria Llanos',
#      'commenter_meta': None,
#      'comment_text': 'Gonzalo Sebastián exacto, por definición los millenials somos los nacidos entre el 81 y 96, aunque algunos autores hablan de una microgeneracion\nentre el 81 y 84, y plantean que los millenials somos los nacidos entre 85 y el 96.',
#      'comment_time': datetime.datetime(2021, 8, 6, 22, 7, 40, 486749),
#      'comment_image': None}]},
#   {'comment_id': '1592512204422975',
#    'comment_url': 'https://facebook.com/1592512204422975',
#    'commenter_id': '1473601312',
#    'commenter_url': None,
#    'commenter_name': 'Diego Martin Sandoval',
#    'commenter_meta': None,
#    'comment_text': 'Centenials!',
#    'comment_time': datetime.datetime(2021, 8, 6, 18, 10, 40, 491173),
#    'comment_image': None},
#   {'comment_id': '1592523104421885',
#    'comment_url': 'https://facebook.com/1592523104421885',
#    'commenter_id': '100004348835620',
#    'commenter_url': None,
#    'commenter_name': 'Moly Resch Sarubba',
#    'commenter_meta': None,
#    'comment_text': 'Xq así la enfermera? Jajaja',
#    'comment_time': datetime.datetime(2021, 8, 6, 18, 10, 40, 499126),
#    'comment_image': None},
#   {'comment_id': '1592544024419793',
#    'comment_url': 'https://facebook.com/1592544024419793',
#    'commenter_id': '100061174450649',
#    'commenter_url': None,
#    'commenter_name': 'Fernando Santiago Guerrero',
#    'commenter_meta': None,
#    'comment_text': 'Comienza la vacunacion de jugadores de fútbol ⚽️',
#    'comment_time': datetime.datetime(2021, 8, 6, 19, 10, 40, 504778),
#    'comment_image': None}],
#  [{'comment_id': '1592398971100965',
#    'comment_url': 'https://facebook.com/1592398971100965',
#    'commenter_id': '100002103998514',
#    'commenter_url': None,
#    'commenter_name': 'Fabian Canepa',
#    'commenter_meta': None,
#    'comment_text': 'Pero nosotros les ganamos en vagos , ladrones, corruptos!!!\nVamooo',
#    'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 45, 786406),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592410634433132',
#      'comment_url': 'https://facebook.com/1592410634433132',
#      'commenter_id': '100001996737440',
#      'commenter_url': None,
#      'commenter_name': 'Marta Mabel Crespi',
#      'commenter_meta': None,
#      'comment_text': 'Fabian Canepa y a que no tienen tantos planes como nosotros eh? Fanfarrones!',
#      'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 46, 222204),
#      'comment_image': None},
#     {'comment_id': '1592415644432631',
#      'comment_url': 'https://facebook.com/1592415644432631',
#      'commenter_id': '1197236274',
#      'commenter_url': None,
#      'commenter_name': 'Gabriel Carrizo',
#      'commenter_meta': None,
#      'comment_text': 'Fabian Canepa seguro que no tienen tantos políticos por cada habitante',
#      'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 46, 225949),
#      'comment_image': None},
#     {'comment_id': '1592416517765877',
#      'comment_url': 'https://facebook.com/1592416517765877',
#      'commenter_id': '1316743586',
#      'commenter_url': None,
#      'commenter_name': 'Andres Lencina',
#      'commenter_meta': None,
#      'comment_text': 'Fabian Canepa En eso siempre vamos primeros, bien tranquilos.',
#      'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 46, 229312),
#      'comment_image': None},
#     {'comment_id': '1592420414432154',
#      'comment_url': 'https://facebook.com/1592420414432154',
#      'commenter_id': '100000246994092',
#      'commenter_url': None,
#      'commenter_name': 'Ana Garcia',
#      'commenter_meta': None,
#      'comment_text': 'Tienen políticos responsables, serios, que TRABAJAN por y para BENEFICIAR A LOS CIUDADANOS, NO, tienen chorros, enquistados en el poder, para enriquecerse, vivir de festicholas, y asegurarse de ZAFAR DE IR PRESOS.',
#      'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 46, 232474),
#      'comment_image': None},
#     {'comment_id': '1592447081096154',
#      'comment_url': 'https://facebook.com/1592447081096154',
#      'commenter_id': '1821394159',
#      'commenter_url': None,
#      'commenter_name': 'Daniel González',
#      'commenter_meta': None,
#      'comment_text': 'Cuantos mundiales ganaron? 😜',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 46, 235718),
#      'comment_image': None},
#     {'comment_id': '1592451961095666',
#      'comment_url': 'https://facebook.com/1592451961095666',
#      'commenter_id': '100015216815198',
#      'commenter_url': None,
#      'commenter_name': 'Yessy Juarezz',
#      'commenter_meta': None,
#      'comment_text': 'Fabian Canepa jajajaja siii...q linda la Argentina...',
#      'comment_time': datetime.datetime(2021, 8, 6, 16, 10, 46, 238797),
#      'comment_image': None},
#     {'comment_id': '1592548657752663',
#      'comment_url': 'https://facebook.com/1592548657752663',
#      'commenter_id': '100011119179810',
#      'commenter_url': None,
#      'commenter_name': 'Jem Calca',
#      'commenter_meta': None,
#      'comment_text': 'Fabian Canepa ...Biba Perron, KA rajo!😁😆🤣✌️',
#      'comment_time': datetime.datetime(2021, 8, 6, 19, 10, 46, 242754),
#      'comment_image': None}]},
#   {'comment_id': '1592547364419459',
#    'comment_url': 'https://facebook.com/1592547364419459',
#    'commenter_id': '1570387163',
#    'commenter_url': None,
#    'commenter_name': 'Fa Iba',
#    'commenter_meta': None,
#    'comment_text': 'Son 4, millones de habitantes en nueva zelanda..... Osea se podria decir un partido de bs as...\nHabría que ver si argentina solo tuviera 4 millones de habitantes calculo que serian otros los números no?..',
#    'comment_time': datetime.datetime(2021, 8, 6, 19, 10, 46, 246422),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592633131077549',
#      'comment_url': 'https://facebook.com/1592633131077549',
#      'commenter_id': '1219183007',
#      'commenter_url': None,
#      'commenter_name': 'Matias Varela',
#      'commenter_meta': None,
#      'comment_text': 'Nosotros tenemos 12 veces más población pero 10 veces más territorio, y sabe dios cuantos más recursos. Aun así tenemos infinitamente menos productividad porque elegimos un sistema social retrogrado e inservible.',
#      'comment_time': datetime.datetime(2021, 8, 6, 22, 3, 46, 631851),
#      'comment_image': None}]},
#   {'comment_id': '1592462231094639',
#    'comment_url': 'https://facebook.com/1592462231094639',
#    'commenter_id': '100004056644899',
#    'commenter_url': None,
#    'commenter_name': 'Adrian Aristei',
#    'commenter_meta': None,
#    'comment_text': 'Decilo de otra manera, en Nueva Zelanda No existe el peronismo! 🙃✌🏾',
#    'comment_time': datetime.datetime(2021, 8, 6, 19, 10, 46, 638770),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592633124410883',
#      'comment_url': 'https://facebook.com/1592633124410883',
#      'commenter_id': '100008103222554',
#      'commenter_url': None,
#      'commenter_name': 'Juan Domingo Zarzabal',
#      'commenter_meta': None,
#      'comment_text': 'Adrian Aristei qué gran verdad',
#      'comment_time': datetime.datetime(2021, 8, 6, 22, 3, 47, 39317),
#      'comment_image': None}]},
#   {'comment_id': '1592500671090795',
#    'comment_url': 'https://facebook.com/1592500671090795',
#    'commenter_id': '100005539456518',
#    'commenter_url': None,
#    'commenter_name': 'Nestor Montorvino',
#    'commenter_meta': None,
#    'comment_text': 'Es facil...tenemos\nel peor gobierno de la historia!!! Y hay pelotudos q todavia defienden a estos inutiles...y siguen cantando la marchita los imbeciles!!!',
#    'comment_time': datetime.datetime(2021, 8, 6, 17, 10, 47, 43950),
#    'comment_image': None},
#   {'comment_id': '1592465077761021',
#    'comment_url': 'https://facebook.com/1592465077761021',
#    'commenter_id': '100005848710129',
#    'commenter_url': None,
#    'commenter_name': 'Sonia Sitar',
#    'commenter_meta': None,
#    'comment_text': 'Hagan estadísticas de planeros , piqueteros ,sindicalistas , políticos ,asesores, ñoquis , cargos inventados todos viviendo del bajo porcentaje que trabaja . Ahí saldremos primeros.',
#    'comment_time': datetime.datetime(2021, 8, 6, 16, 10, 47, 50862),
#    'comment_image': None},
#   {'comment_id': '1592401764434019',
#    'comment_url': 'https://facebook.com/1592401764434019',
#    'commenter_id': '100004694802928',
#    'commenter_url': None,
#    'commenter_name': 'Honda Garcia',
#    'commenter_meta': None,
#    'comment_text': 'Que alguien me saque estos datos .ingreso de mauricio .dólar 9,40.salida del estado ,63,00 por cada uno...el país estaba girando en las importaciones..\n.... La dupla científicos.ing\nresos 64 pesos x dólar .país con cero movimiento en ingreso e egresos ..18 meses después 180 pesos x cada uno..con un tope de personas de 200 por mes para comprar ....dónde y por qué aumento tanto en poco tiempo sin que el país este en marcha como con Mauricio...osea\nque la bicicleta financiera no la tenía el gato como decían la tiene está dupla en el estado .',
#    'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 47, 57056),
#    'comment_image': None,
#    'replies': [{'comment_id': '1592410944433101',
#      'comment_url': 'https://facebook.com/1592410944433101',
#      'commenter_id': '100001262957062',
#      'commenter_url': None,
#      'commenter_name': 'Roberto Tula Malgrandi',
#      'commenter_meta': None,
#      'comment_text': 'Honda Garcia Vos sabés que Macri dejó deuda con el PBI y por eso aumentó tanto el dólar?',
#      'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 47, 639060),
#      'comment_image': None},
#     {'comment_id': '1592411357766393',
#      'comment_url': 'https://facebook.com/1592411357766393',
#      'commenter_id': '1590583213',
#      'commenter_url': None,
#      'commenter_name': 'Renso Daniel',
#      'commenter_meta': None,
#      'comment_text': 'Honda Garcia el dólar cuando asume Macri estaba 9,87 legal y 15,4 el blue. Que todos sabían que el precio real era el del blue lo otro siempre fue mentira.\nAumentan por la emisión de pesos, como no aflojan con la maquinita y la usan para dar los subsidios y bonos la inflación crece a pasao agigantados',
#      'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 47, 642504),
#      'comment_image': None},
#     {'comment_id': '1592414244432771',
#      'comment_url': 'https://facebook.com/1592414244432771',
#      'commenter_id': '100004694802928',
#      'commenter_url': None,
#      'commenter_name': 'Honda Garcia',
#      'commenter_meta': None,
#      'comment_text': 'Roberto Tula Malgrandi para estoy preguntando. Que alguien me diga el porque del aumento de cada dólar en dos fracciones de mandato.uno de 4 años y otro de 18 meses .es más el anterior el FMI le dió 53 mil millones.y no aumento tanto .que esté en este tiempo ya que no recibió tal préstamo y el país está totalmente parado con una pandemia más larga de la historia..y más aún que el dólar es oferta x demanda el precio..de cada dólar',
#      'comment_time': datetime.datetime(2021, 8, 6, 14, 10, 47, 645677),
#      'comment_image': None},
#     {'comment_id': '1592423097765219',
#      'comment_url': 'https://facebook.com/1592423097765219',
#      'commenter_id': '100004694802928',
#      'commenter_url': None,
#      'commenter_name': 'Honda Garcia',
#      'commenter_meta': None,
#      'comment_text': 'Renso Daniel bueno estamos rescatando datos bien .9,90 cada uno ,15,4 blue...este ingreso 64.y el blue a cuánto .x que hoy veo el blue a 180 y el oficial a 99 pongamos es el doble por cada uno y en menos de 4 años de mandato y solamente los mortales pueden sacar 200 x mes no da nunca la demanda de dólares por el precio que lo que vale en el mercado .si el país está parado ..',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 47, 649034),
#      'comment_image': None},
#     {'comment_id': '1592424717765057',
#      'comment_url': 'https://facebook.com/1592424717765057',
#      'commenter_id': '1131414210',
#      'commenter_url': None,
#      'commenter_name': 'Hernán Ezequiel Vivas',
#      'commenter_meta': None,
#      'comment_text': 'Es muy simple, es un estado que gasta mas de lo que ingresa, se endeuda, le dan a la maquinita para apalear el deficit y genera inflacion.',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 47, 652199),
#      'comment_image': None},
#     {'comment_id': '1592432557764273',
#      'comment_url': 'https://facebook.com/1592432557764273',
#      'commenter_id': '1590583213',
#      'commenter_url': None,
#      'commenter_name': 'Renso Daniel',
#      'commenter_meta': None,
#      'comment_text': 'Honda Garcia ojo yo solo quería aportar un dato. Estoy de acuerdo con vos. Tienen el país parado y es por culpa de ellos',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 47, 655383),
#      'comment_image': None},
#     {'comment_id': '1592434134430782',
#      'comment_url': 'https://facebook.com/1592434134430782',
#      'commenter_id': '1590583213',
#      'commenter_url': None,
#      'commenter_name': 'Renso Daniel',
#      'commenter_meta': None,
#      'comment_text': 'Hernán Ezequiel Vivas exacto tiene un alto déficit fiscal.\nY cada vez hay menos entradas de divisas. Por eso para hacer el pago de los gastos internos se ponen a imprimir, sin darte cuenta le dan a unos e indirectamente le sacan a otro.\nSi vos tenés mil pesos en la mano y el estado imprime y reparte mil pesos a 10 personas tus mil pesos ya valen el 10% de lo que valía antes, o sea indirectamente te está robando para darle a otros',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 47, 658657),
#      'comment_image': None},
#     {'comment_id': '1592434407764088',
#      'comment_url': 'https://facebook.com/1592434407764088',
#      'commenter_id': '100011751882164',
#      'commenter_url': None,
#      'commenter_name': 'Carlos Borenszweig',
#      'commenter_meta': None,
#      'comment_text': 'Renso Daniel EEUU el país que más emite en el mundo, porqué tiene tan baja inflación o la teoría no funciona allá?',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 47, 661930),
#      'comment_image': None},
#     {'comment_id': '1592436597763869',
#      'comment_url': 'https://facebook.com/1592436597763869',
#      'commenter_id': '1590583213',
#      'commenter_url': None,
#      'commenter_name': 'Renso Daniel',
#      'commenter_meta': None,
#      'comment_text': 'Carlos Borenszweig porque crece su reserva en oro.\nPara emitir billetes de curso legal tenés que tener un respaldo de la moneda, antiguamente era en oro, hoy en muchos países se usa la reserva en dólares porque es una de las monedas mas fuertes del mundo. Tienen baja inflación porque la impresión de la moneda billete es paralela al crecimiento del país, ya sea en la explotación del oro, petróleo, acciones en la bolsa etcétera',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 47, 665118),
#      'comment_image': None},
#     {'comment_id': '1592440441096818',
#      'comment_url': 'https://facebook.com/1592440441096818',
#      'commenter_id': '1590583213',
#      'commenter_url': None,
#      'commenter_name': 'Renso Daniel',
#      'commenter_meta': None,
#      'comment_text': 'Roberto Tula Malgrandi campeón me parece que estás medio perdido. Dejo deuda con el PBI?\nTe cuento en el segundo mandato de CFK lo asume con una deuda externa de 187 mil millones de dólares, cuando se retira lo deja en 266 mil millones de dólares y las reservas del banco central vacías. Para que el impacto sea menor crea el 35% de retenciones para el sector agropecuario.\nO sea quiso que el sector agropecuario pague la deuda generada por el sector político, eso dió una deuda anual en relación con el PBI de 52%, asume Macri saca las retenciones y el porcentaje de la deuda en relación al PBI se dispara al 92%, vos entendés que te estuvieron mintiendo?',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 47, 668837),
#      'comment_image': None},
#     {'comment_id': '1592442087763320',
#      'comment_url': 'https://facebook.com/1592442087763320',
#      'commenter_id': '1590583213',
#      'commenter_url': None,
#      'commenter_name': 'Renso Daniel',
#      'commenter_meta': None,
#      'comment_text': 'Roberto Tula Malgrandi http://\nwww.bcra.gov.ar/ mira ahí está la página del banco central de la Nación, ahí podés buscar los reportes',
#      'comment_time': datetime.datetime(2021, 8, 6, 15, 10, 47, 673070),
#      'comment_image': 'http://www.bcra.gov.ar/'},
#     {'comment_id': '1592452134428982',
#      'comment_url': 'https://facebook.com/1592452134428982',
#      'commenter_id': '100000346061670',
#      'commenter_url': None,
#      'commenter_name': 'Roman Rodrigo',
#      'commenter_meta': None,
#      'comment_text': 'Renso Daniel gracias por la info, servirá para debates de que ellos deuda 0, saludos',
#      'comment_time': datetime.datetime(2021, 8, 6, 16, 10, 47, 676138),
#      'comment_image': None},
#     {'comment_id': '1592457887761740',
#      'comment_url': 'https://facebook.com/1592457887761740',
#      'commenter_id': '1384158578',
#      'commenter_url': None,
#      'commenter_name': 'Diego Sebastian Bermani',
#      'commenter_meta': None,
#      'comment_text': 'Honda Garcia ahh pero Macri... Jajajjaa',
#      'comment_time': datetime.datetime(2021, 8, 6, 16, 10, 47, 679131),
#      'comment_image': None},
#     {'comment_id': '1592497741091088',
#      'comment_url': 'https://facebook.com/1592497741091088',
#      'commenter_id': '100003608315082',
#      'commenter_url': None,
#      'commenter_name': 'Juan Larrea',
#      'commenter_meta': None,
#      'comment_text': 'Honda Garcia la respuesta es simple: ah pero macri, ah pero la deuda, ah pero pandemia, ah pero con macri tendriamos 10 mil muertos; etc.',
#      'comment_time': datetime.datetime(2021, 8, 6, 17, 10, 47, 683517),
#      'comment_image': None},
#     {'comment_id': '1592506544423541',
#      'comment_url': 'https://facebook.com/1592506544423541',
#      'commenter_id': '1181558014',
#      'commenter_url': None,
#      'commenter_name': 'José Luis Leiva',
#      'commenter_meta': None,
#      'comment_text': 'Honda Garcia corrección 9,40+cepo , alrededor de 14 el valor real, cuando entró Macri.',
#      'comment_time': datetime.datetime(2021, 8, 6, 17, 10, 47, 687411),
#      'comment_image': None},
#     {'comment_id': '1592507344423461',
#      'comment_url': 'https://facebook.com/1592507344423461',
#      'commenter_id': '1181558014',
#      'commenter_url': None,
# ...
#    'commenter_name': 'Mariu Sand',
#    'commenter_meta': None,
#    'comment_text': 'El sistema está estrictamente echo para darle el 100% de las ganancias a los "de arriba" osea los políticos y presidente y a todos los que trabajan en la municipalidad y a todos sus familiares y conocidos.no al pueblo.ok.',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590441801296682',
#    'comment_url': 'https://facebook.com/1590441801296682',
#    'commenter_id': '100034775405026',
#    'commenter_url': None,
#    'commenter_name': 'Laura Correa',
#    'commenter_meta': None,
#    'comment_text': 'Se q aveces nos decimos q no podemos hacer nada..pero algo podemos hacer NO IR A VOTAR A NINGUNO ...seamos conscientes y responsables!!🙏🙏\nO si no vamos a tener q salir a las calles como en jujuy 💪',
#    'comment_time': None,
#    'comment_image': None,
#    'replies': [{'comment_id': '1590563064617889',
#      'comment_url': 'https://facebook.com/1590563064617889',
#      'commenter_id': '100002509832033',
#      'commenter_url': None,
#      'commenter_name': 'Javier Ocampo',
#      'commenter_meta': None,
#      'comment_text': 'Laura Correa si no votas con más razón seguirán los mismos porque ellos ya tienen su aparato clientelar como para retener un mandato.\nTenes para elegir, sólo hay que buscar y no son precisamente los que polarizan los medios',
#      'comment_time': None,
#      'comment_image': None},
#     {'comment_id': '1591080914566104',
#      'comment_url': 'https://facebook.com/1591080914566104',
#      'commenter_id': '1158736210',
#      'commenter_url': None,
#      'commenter_name': 'Maria Angélica Vicat',
#      'commenter_meta': None,
#      'comment_text': 'Laura Correa bueno...bah...l\nos franceses salieron a la calle un 14 de julio y al gobierno no le fue muy bien que se diga...',
#      'comment_time': None,
#      'comment_image': None}]},
#   {'comment_id': '1590421827965346',
#    'comment_url': 'https://facebook.com/1590421827965346',
#    'commenter_id': '515846220',
#    'commenter_url': None,
#    'commenter_name': 'Francisco Urioste',
#    'commenter_meta': None,
#    'comment_text': 'Y así en TODO el mundo donde el Socialismo haya puesto las garras',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590771884597007',
#    'comment_url': 'https://facebook.com/1590771884597007',
#    'commenter_id': '100053233944309',
#    'commenter_url': None,
#    'commenter_name': 'Carlos Sosa',
#    'commenter_meta': None,
#    'comment_text': 'Es mas rentable un plan descansar que producir y para colmo te deslomas laburando, pagas impuestos para pagarle al Brian la cerveza. A eso agrégale que tenés que aguantarte a los fracasados del gobierno de cada turno, que no tiene idea de lo que es invertir, producir. Parásitos que viven del estado o sea de mi o de vos. FRACASADOS que fundieron un país entero.',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590827704591425',
#    'comment_url': 'https://facebook.com/1590827704591425',
#    'commenter_id': '1547508245',
#    'commenter_url': None,
#    'commenter_name': 'Ema CA',
#    'commenter_meta': None,
#    'comment_text': 'HAY QUE IRSE AFUERA... Como sea, este pais no da para mas, ya ni estudiando y esforzándote llegas a algo en esta bosta de pais lleno de corrupción , delincuencia y vagancia...',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590431704631025',
#    'comment_url': 'https://facebook.com/1590431704631025',
#    'commenter_id': '100000274202050',
#    'commenter_url': None,
#    'commenter_name': 'Marcela Müller',
#    'commenter_meta': None,
#    'comment_text': 'El impuesto a las Ganancias lo va a tener que pagar aunque no le quede ninguna ganancia... Tristísimo.',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590419377965591',
#    'comment_url': 'https://facebook.com/1590419377965591',
#    'commenter_id': '640511838',
#    'commenter_url': None,
#    'commenter_name': 'Santi De Agostini',
#    'commenter_meta': None,
#    'comment_text': 'Tan cierto que duele! A eso súmale escuela privada, salud privada y seguridad privada. Por qué nada funciona bien. Pagamos impuestos al pedo!!!',
#    'comment_time': None,
#    'comment_image': None,
#    'replies': [{'comment_id': '1590423051298557',
#      'comment_url': 'https://facebook.com/1590423051298557',
#      'commenter_id': '100068103537306',
#      'commenter_url': None,
#      'commenter_name': 'Alberto Chacón',
#      'commenter_meta': None,
#      'comment_text': 'Santi De Agostini Momentito, al pedo no, que los gatos de Plin Plin no son baratos',
#      'comment_time': None,
#      'comment_image': None},
#     {'comment_id': '1590471104627085',
#      'comment_url': 'https://facebook.com/1590471104627085',
#      'commenter_id': '640511838',
#      'commenter_url': None,
#      'commenter_name': 'Santi De Agostini',
#      'commenter_meta': None,
#      'comment_text': 'Alberto Chacón jajaja bueno! Pero nosotros esos no los vemos!',
#      'comment_time': None,
#      'comment_image': None},
#     {'comment_id': '1590472787960250',
#      'comment_url': 'https://facebook.com/1590472787960250',
#      'commenter_id': '100068103537306',
#      'commenter_url': None,
#      'commenter_name': 'Alberto Chacón',
#      'commenter_meta': None,
#      'comment_text': 'Santi De Agostini Asi es mi amigo, pero lo pagamos',
#      'comment_time': None,
#      'comment_image': None},
#     {'comment_id': '1590504327957096',
#      'comment_url': 'https://facebook.com/1590504327957096',
#      'commenter_id': '640511838',
#      'commenter_url': None,
#      'commenter_name': 'Santi De Agostini',
#      'commenter_meta': None,
#      'comment_text': 'Alberto Chacón triste realidad',
#      'comment_time': None,
#      'comment_image': None},
#     {'comment_id': '1590796777927851',
#      'comment_url': 'https://facebook.com/1590796777927851',
#      'commenter_id': '100068103537306',
#      'commenter_url': None,
#      'commenter_name': 'Alberto Chacón',
#      'commenter_meta': None,
#      'comment_text': 'Santi De Agostini Al menos que saquen el plan "putas para todos"',
#      'comment_time': None,
#      'comment_image': None}]},
#   {'comment_id': '1590428391298023',
#    'comment_url': 'https://facebook.com/1590428391298023',
#    'commenter_id': '100007960812075',
#    'commenter_url': None,
#    'commenter_name': 'Mariela Alonso',
#    'commenter_meta': None,
#    'comment_text': 'Cuanto cuesta querés trabajar en este país. Tan real y triste!!!!',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590849257922603',
#    'comment_url': 'https://facebook.com/1590849257922603',
#    'commenter_id': '1145350118',
#    'commenter_url': None,
#    'commenter_name': 'Mariana Carreras',
#    'commenter_meta': None,
#    'comment_text': 'Así es! Imposible progresar con éstos bastardos de gobernantes!!! Los únicos beneficiados son los que no trabajan y las que se dedican a tener cría, sin comparar con los animales!',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590504551290407',
#    'comment_url': 'https://facebook.com/1590504551290407',
#    'commenter_id': '100003602125688',
#    'commenter_url': None,
#    'commenter_name': 'Marcela Rivero',
#    'commenter_meta': None,
#    'comment_text': 'El primero le asegura el voto, el segundo, no. Sencillo. En peronia estamos en bancarrota pero siguen sumando subsidios y planes. 🤮',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590405971300265',
#    'comment_url': 'https://facebook.com/1590405971300265',
#    'commenter_id': '100001701370851',
#    'commenter_url': None,
#    'commenter_name': 'Jimmy Adaro',
#    'commenter_meta': None,
#    'comment_text': 'Ojo que "hacerte rico" implica ganar más de US$ 1M por año. Argentina ex país...',
#    'comment_time': None,
#    'comment_image': None,
#    'replies': [{'comment_id': '1590464304627765',
#      'comment_url': 'https://facebook.com/1590464304627765',
#      'commenter_id': '1638247917',
#      'commenter_url': None,
#      'commenter_name': 'Carina Martinez',
#      'commenter_meta': None,
#      'comment_text': 'Jimmy Adaro Con 2 millones en bienes, pagas impuestos a la ganancias...es un autito',
#      'comment_time': None,
#      'comment_image': None},
#     {'comment_id': '1590464511294411',
#      'comment_url': 'https://facebook.com/1590464511294411',
#      'commenter_id': '100001701370851',
#      'commenter_url': None,
#      'commenter_name': 'Jimmy Adaro',
#      'commenter_meta': None,
#      'comment_text': 'Carina Martinez ¿2 millones de qué?',
#      'comment_time': None,
#      'comment_image': None},
#     {'comment_id': '1590482557959273',
#      'comment_url': 'https://facebook.com/1590482557959273',
#      'commenter_id': '1638247917',
#      'commenter_url': None,
#      'commenter_name': 'Carina Martinez',
#      'commenter_meta': None,
#      'comment_text': 'Jimmy Adaro PESOS Hoy tenes una casa de 100 000 dolares y un auto y ya pagas impuestos a los bienes, porque con el autito,llegas a los 2 millones extras y te empiezan a fajar🤷🏻\u200d♀️',
#      'comment_time': None,
#      'comment_image': None}]},
#   {'comment_id': '1591322341208628',
#    'comment_url': 'https://facebook.com/1591322341208628',
#    'commenter_id': '1242858507',
#    'commenter_url': None,
#    'commenter_name': 'Débora Chiama',
#    'commenter_meta': None,
#    'comment_text': 'En qué clase de País nos hemos convertido?',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590574024616793',
#    'comment_url': 'https://facebook.com/1590574024616793',
#    'commenter_id': '100000490707251',
#    'commenter_url': None,
#    'commenter_name': 'Marito Berrini',
#    'commenter_meta': None,
#    'comment_text': 'Si te queda ganancia impuesto a las ganancias? Ese te lo sacan siempre',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590954467912082',
#    'comment_url': 'https://facebook.com/1590954467912082',
#    'commenter_id': '100000507141738',
#    'commenter_url': None,
#    'commenter_name': 'Daniel Silva',
#    'commenter_meta': None,
#    'comment_text': 'que triste realidad,gracia\ns politicos , todos. que destruyeron al pais',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590505551290307',
#    'comment_url': 'https://facebook.com/1590505551290307',
#    'commenter_id': '1248682565',
#    'commenter_url': None,
#    'commenter_name': 'Mirtha Sosa',
#    'commenter_meta': None,
#    'comment_text': 'Yo ahí mismo le doy mi DNI y que me de un Plan!! (a la m... la PyME!!) JEJE',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590437487963780',
#    'comment_url': 'https://facebook.com/1590437487963780',
#    'commenter_id': '100000621830643',
#    'commenter_url': None,
#    'commenter_name': 'Pimpo Leri',
#    'commenter_meta': None,
#    'comment_text': 'Es así, es la consecuencia de vivir en un país donde a quien gobierna solo le importa perpetuarse en el poder y para eso implementa planes sociales para algunos que representan potenciales votantes 🤡🎪🎡🎠',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1592454154428780',
#    'comment_url': 'https://facebook.com/1592454154428780',
#    'commenter_id': '100016738277576',
#    'commenter_url': None,
#    'commenter_name': 'Angel Maimone',
#    'commenter_meta': None,
#    'comment_text': 'Triste realidad y faltó una\nTENES QUE TRABAJAR!!!!!!!\n!!!!',
#    'comment_time': datetime.datetime(2021, 8, 6, 16, 13, 7, 776269),
#    'comment_image': None},
#   {'comment_id': '1590538954620300',
#    'comment_url': 'https://facebook.com/1590538954620300',
#    'commenter_id': '100025136949971',
#    'commenter_url': None,
#    'commenter_name': 'Mirta Fernandez',
#    'commenter_meta': None,
#    'comment_text': 'Que lamentable se tienen que ir a vivir a un lugAr domde nadie los. Bea osea un desierto y Dios los ponga en su lugar mo Sirven mas que para destruir nuestro pais ladrones',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590897094584486',
#    'comment_url': 'https://facebook.com/1590897094584486',
#    'commenter_id': '100008142543174',
#    'commenter_url': None,
#    'commenter_name': 'Maria Bedek',
#    'commenter_meta': None,
#    'comment_text': 'Mejor preparar las valijas y mandarse a mudar a otro pais!!!!',
#    'comment_time': None,
#    'comment_image': None,
#    'replies': [{'comment_id': '1591099261230936',
#      'comment_url': 'https://facebook.com/1591099261230936',
#      'commenter_id': '100017368625330',
#      'commenter_url': None,
#      'commenter_name': 'Alicia Noemi Severino',
#      'commenter_meta': None,
#      'comment_text': 'Maria Bedek para los jovenes si, pero los mayores tristemente no tenemos mas futuro!!!😡',
#      'comment_time': None,
#      'comment_image': None}]},
#   {'comment_id': '1590434407964088',
#    'comment_url': 'https://facebook.com/1590434407964088',
#    'commenter_id': '100055905042097',
#    'commenter_url': None,
#    'commenter_name': 'José Maria Escobar',
#    'commenter_meta': None,
#    'comment_text': 'Que buen gobierno ,ESPECTACULAR,d\nespués hablamos de MACRI',
#    'comment_time': None,
#    'comment_image': None,
#    'replies': [{'comment_id': '1590500994624096',
#      'comment_url': 'https://facebook.com/1590500994624096',
#      'commenter_id': '100002256935771',
#      'commenter_url': None,
#      'commenter_name': 'Yolanda Mirtha Dominguez',
#      'commenter_meta': None,
#      'comment_text': 'José Maria Escobar MIL VECES MACRI..........\nEN TODOOOOOOO',
#      'comment_time': None,
#      'comment_image': None}]},
#   {'comment_id': '1590492531291609',
#    'comment_url': 'https://facebook.com/1590492531291609',
#    'commenter_id': '724627052',
#    'commenter_url': None,
#    'commenter_name': 'Alejandra Fortunato',
#    'commenter_meta': None,
#    'comment_text': 'Que poca iniciativa e incentivo para una pyme en este país!!!! Que desgracia!!! Encima son las que dan trabajo!!! El problema es ese, que nadie quiere trabajar….',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590432281297634',
#    'comment_url': 'https://facebook.com/1590432281297634',
#    'commenter_id': '100009525815041',
#    'commenter_url': None,
#    'commenter_name': 'Lorena Vera',
#    'commenter_meta': None,
#    'comment_text': 'Tal cual ... Encima que querés trabajar te cobran diez mil impuestos y te piden cien mil requisitos...el\nmundo del revés',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590432507964278',
#    'comment_url': 'https://facebook.com/1590432507964278',
#    'commenter_id': '1233596664',
#    'commenter_url': None,
#    'commenter_name': 'Gustavo Aldeco',
#    'commenter_meta': None,
#    'comment_text': 'Siempre y cuando no tengas algún juicio laboral jaja',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590432951297567',
#    'comment_url': 'https://facebook.com/1590432951297567',
#    'commenter_id': '1589272412',
#    'commenter_url': None,
#    'commenter_name': 'Annie Galeano',
#    'commenter_meta': None,
#    'comment_text': 'Creo que una vez que los jueces empiecen a justificar sus suculentos sueldos y pagar impuestos a la riqueza, digo... a la ganancia, entonces, todos podríamos pagar impuestos para que de una vez por todas tengamos salud y educación pública de primera y acabar con el negocio de la educación privada.',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590434494630746',
#    'comment_url': 'https://facebook.com/1590434494630746',
#    'commenter_id': '100001692858305',
#    'commenter_url': None,
#    'commenter_name': 'Marcela Gandulla',
#    'commenter_meta': None,
#    'comment_text': 'Ni hablar de las cuotas "sindicales"',
#    'comment_time': None,
#    'comment_image': None},
#   {'comment_id': '1590430304631165',
#    'comment_url': 'https://facebook.com/1590430304631165',
#    'commenter_id': '1329724092',
#    'commenter_url': None,
#    'commenter_name': 'Ruben Prosperi',
#    'commenter_meta': None,
#    'comment_text': 'La triste realidad con el peor populismo peroncho de la historia',
#    'comment_time': None,
#    'comment_image': None}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
def get_comment_keys(comments, c_dict={}):
    for c in comments:
        for k in c:
            if not k in c_dict:
                c_dict[k] = 1
            else:
                c_dict[k] += 1
    return c_dict

# %%
dict_comments = {}

for c in comments_:
    if c:
        dict_comments = get_comment_keys(c, dict_comments)

dict_comments
# Out:
# {'comment_id': 265,
#  'comment_url': 265,
#  'commenter_id': 265,
#  'commenter_url': 265,
#  'commenter_name': 265,
#  'commenter_meta': 265,
#  'comment_text': 265,
#  'comment_time': 265,
#  'comment_image': 265,
#  'replies': 37}

# %%
import pymongo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c275cfc49946> in <module>
# ----> 1 import pymongo
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
# !pip -V
# Out:
# pip 21.1.2 from /Users/tiaqui/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pip (python 3.9)

# %%
from pymongo import MongoClient, errors

PORT = '27017'

# %%
# import the MongoClient class
from pymongo import MongoClient, errors

# global variables for MongoDB host (default port is 27017)
#DOMAIN = '172.17.0.4'
#DOMAIN='localhost'
PORT = '27017'

# use a try-except indentation to catch MongoClient() errors
try:
    # try to instantiate a client instance
    client = MongoClient(
        host = [ str(DOMAIN) + ":" + str(PORT) ],
        serverSelectionTimeoutMS = 3000#, # 3 second timeout
#        username = "objectrocket",
#        password = "1234",
    )

    # print the version of MongoDB server if connection successful
    print ("server version:", client.server_info()["version"])

    # get the database_names from the MongoClient()
    database_names = client.list_database_names()
 t
except errors.ServerSelectionTimeoutError as err:
    # set the client and DB name list to 'None' and `[]` if exception
    client = None
    database_names = []

    # catch pymongo.errors.ServerSelectionTimeoutError
    print ("pymongo ERROR:", err)

print ("\ndatabases:", database_names)
# Out:
# pymongo ERROR: No servers found yet, Timeout: 3.0s, Topology Description: <TopologyDescription id: 60d806f8df8d9d6f87ac449b, topology_type: Single, servers: [<ServerDescription ('172.17.0.4', 27017) server_type: Unknown, rtt: None>]>
#
# databases: []
